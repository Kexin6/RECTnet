# %% [markdown]
# ## Check GPU states

# %%
# memory footprint support libraries/code
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
 process = psutil.Process(os.getpid())
 print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
 print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()
# Out:
# Collecting gputil
#   Downloading https://files.pythonhosted.org/packages/ed/0e/5c61eedde9f6c87713e89d794f01e378cfd9565847d4576fa627d758c554/GPUtil-1.4.0.tar.gz
# Building wheels for collected packages: gputil
#   Building wheel for gputil (setup.py) ... done
#   Created wheel for gputil: filename=GPUtil-1.4.0-cp36-none-any.whl size=7413 sha256=28c833234f34a992452bf59d492ec132fc1840b83e834394b204d477dace52f8
#   Stored in directory: /root/.cache/pip/wheels/3d/77/07/80562de4bb0786e5ea186911a2c831fdd0018bda69beab71fd
# Successfully built gputil
# Installing collected packages: gputil
# Successfully installed gputil-1.4.0
# Requirement already satisfied: psutil in /usr/local/lib/python3.6/dist-packages (5.4.8)
# Requirement already satisfied: humanize in /usr/local/lib/python3.6/dist-packages (0.5.1)
# Gen RAM Free: 12.8 GB  | Proc size: 157.5 MB
# GPU RAM Free: 11441MB | Used: 0MB | Util   0% | Total 11441MB

# %%
import numpy as np
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torch.utils.data.sampler import SubsetRandomSampler
import torchvision.transforms as transforms
import matplotlib.pyplot as plt # for plotting
import torch.optim as optim #for gradient descent

torch.manual_seed(1) # set the random seed

# %%
# obtain data
from torchvision import datasets, transforms

# %% [markdown]
# ## Download datasets

# %%
# set global path
PATH_TRAIN = "/content/train_set"
PATH_VALID = "/content/valid_set"

# %%
# !cd /content/
# !rm -r /content/* # clean up disks
# !mkdir train_set_tensor
# !mkdir valid_set_tensor

# %%
# !wget http://yucanwu.com/aps360/set_a_5600.zip
# !mkdir train_set
# !unzip set_a_5600.zip -d ./train_set

# !wget http://yucanwu.com/aps360/set_v_3500.zip
# !unzip -q set_v_3500
# !mv dataset_valid valid_set

# !ls
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: ./train_set/0/406.jpg
#   inflating: ./train_set/0/409.jpg
#   inflating: ./train_set/0/41.jpg
#   inflating: ./train_set/0/42.jpg
#   inflating: ./train_set/0/425.jpg
#   inflating: ./train_set/0/433.jpg
#   inflating: ./train_set/0/434.jpg
#   inflating: ./train_set/0/452.jpg
#   inflating: ./train_set/0/454.jpg
#   inflating: ./train_set/0/461.jpg
#   inflating: ./train_set/0/469.jpg
#   inflating: ./train_set/0/470.jpg
#   inflating: ./train_set/0/476.jpg
#   inflating: ./train_set/0/48.jpg
#   inflating: ./train_set/0/482.jpg
#   inflating: ./train_set/0/489.jpg
#   inflating: ./train_set/0/49.jpg
#   inflating: ./train_set/0/491.jpg
#   inflating: ./train_set/0/496.jpg
#   inflating: ./train_set/0/499.jpg
#   inflating: ./train_set/0/503.jpg
#   inflating: ./train_set/0/508.jpg
#   inflating: ./train_set/0/514.jpg
#   inflating: ./train_set/0/516.jpg
#   inflating: ./train_set/0/52.jpg
#   inflating: ./train_set/0/520.jpg
#   inflating: ./train_set/0/521.jpg
#   inflating: ./train_set/0/523.jpg
#   inflating: ./train_set/0/528.jpg
#   inflating: ./train_set/0/53.jpg
#   inflating: ./train_set/0/531.jpg
#   inflating: ./train_set/0/538.jpg
#   inflating: ./train_set/0/542.jpg
#   inflating: ./train_set/0/545.jpg
#   inflating: ./train_set/0/549.jpg
#   inflating: ./train_set/0/55.jpg
#   inflating: ./train_set/0/555.jpg
#   inflating: ./train_set/0/557.jpg
#   inflating: ./train_set/0/560.jpg
#   inflating: ./train_set/0/575.jpg
#   inflating: ./train_set/0/578.jpg
#   inflating: ./train_set/0/579.jpg
#   inflating: ./train_set/0/580.jpg
#   inflating: ./train_set/0/582.jpg
#   inflating: ./train_set/0/583.jpg
#   inflating: ./train_set/0/584.jpg
#   inflating: ./train_set/0/587.jpg
#   inflating: ./train_set/0/589.jpg
#   inflating: ./train_set/0/593.jpg
#   inflating: ./train_set/0/597.jpg
#   inflating: ./train_set/0/599.jpg
#   inflating: ./train_set/0/606.jpg
#   inflating: ./train_set/0/607.jpg
#   inflating: ./train_set/0/608.jpg
#   inflating: ./train_set/0/61.jpg
#   inflating: ./train_set/0/612.jpg
#   inflating: ./train_set/0/614.jpg
#   inflating: ./train_set/0/618.jpg
#   inflating: ./train_set/0/62.jpg
#   inflating: ./train_set/0/621.jpg
#   inflating: ./train_set/0/628.jpg
#   inflating: ./train_set/0/63.jpg
#   inflating: ./train_set/0/630.jpg
#   inflating: ./train_set/0/633.jpg
#   inflating: ./train_set/0/635.jpg
#   inflating: ./train_set/0/636.jpg
#   inflating: ./train_set/0/64.jpg
#   inflating: ./train_set/0/641.jpg
#   inflating: ./train_set/0/645.jpg
#   inflating: ./train_set/0/647.jpg
#   inflating: ./train_set/0/648.jpg
#   inflating: ./train_set/0/660.jpg
#   inflating: ./train_set/0/661.jpg
#   inflating: ./train_set/0/664.jpg
#   inflating: ./train_set/0/667.jpg
#   inflating: ./train_set/0/67.jpg
#   inflating: ./train_set/0/670.jpg
#   inflating: ./train_set/0/671.jpg
#   inflating: ./train_set/0/672.jpg
#   inflating: ./train_set/0/675.jpg
#   inflating: ./train_set/0/68.jpg
#   inflating: ./train_set/0/680.jpg
#   inflating: ./train_set/0/681.jpg
#   inflating: ./train_set/0/685.jpg
#   inflating: ./train_set/0/686.jpg
#   inflating: ./train_set/0/687.jpg
#   inflating: ./train_set/0/689.jpg
#   inflating: ./train_set/0/690.jpg
#   inflating: ./train_set/0/696.jpg
#   inflating: ./train_set/0/698.jpg
#   inflating: ./train_set/0/7.jpg
#   inflating: ./train_set/0/70.jpg
#   inflating: ./train_set/0/706.jpg
#   inflating: ./train_set/0/707.jpg
#   inflating: ./train_set/0/71.jpg
#   inflating: ./train_set/0/714.jpg
#   inflating: ./train_set/0/716.jpg
#   inflating: ./train_set/0/719.jpg
#   inflating: ./train_set/0/72.jpg
#   inflating: ./train_set/0/720.jpg
#   inflating: ./train_set/0/728.jpg
#   inflating: ./train_set/0/729.jpg
#   inflating: ./train_set/0/730.jpg
#   inflating: ./train_set/0/736.jpg
#   inflating: ./train_set/0/757.jpg
#   inflating: ./train_set/0/763.jpg
#   inflating: ./train_set/0/764.jpg
#   inflating: ./train_set/0/766.jpg
#   inflating: ./train_set/0/769.jpg
#   inflating: ./train_set/0/778.jpg
#   inflating: ./train_set/0/786.jpg
#   inflating: ./train_set/0/790.jpg
#   inflating: ./train_set/0/792.jpg
#   inflating: ./train_set/0/793.jpg
#   inflating: ./train_set/0/796.jpg
#   inflating: ./train_set/0/80.jpg
#   inflating: ./train_set/0/805.jpg
#   inflating: ./train_set/0/816.jpg
#   inflating: ./train_set/0/819.jpg
#   inflating: ./train_set/0/82.jpg
#   inflating: ./train_set/0/823.jpg
#   inflating: ./train_set/0/825.jpg
#   inflating: ./train_set/0/828.jpg
#   inflating: ./train_set/0/829.jpg
#   inflating: ./train_set/0/83.jpg
#   inflating: ./train_set/0/84.jpg
#   inflating: ./train_set/0/842.jpg
#   inflating: ./train_set/0/843.jpg
#   inflating: ./train_set/0/844.jpg
#   inflating: ./train_set/0/846.jpg
#   inflating: ./train_set/0/85.jpg
#   inflating: ./train_set/0/851.jpg
#   inflating: ./train_set/0/853.jpg
#   inflating: ./train_set/0/855.jpg
#   inflating: ./train_set/0/861.jpg
#   inflating: ./train_set/0/878.jpg
#   inflating: ./train_set/0/88.jpg
#   inflating: ./train_set/0/882.jpg
#   inflating: ./train_set/0/886.jpg
#   inflating: ./train_set/0/889.jpg
#   inflating: ./train_set/0/890.jpg
#   inflating: ./train_set/0/892.jpg
#   inflating: ./train_set/0/894.jpg
#   inflating: ./train_set/0/895.jpg
#   inflating: ./train_set/0/897.jpg
#   inflating: ./train_set/0/90.jpg
#   inflating: ./train_set/0/907.jpg
#   inflating: ./train_set/0/909.jpg
#   inflating: ./train_set/0/91.jpg
#   inflating: ./train_set/0/913.jpg
#   inflating: ./train_set/0/915.jpg
#   inflating: ./train_set/0/920.jpg
#   inflating: ./train_set/0/922.jpg
#   inflating: ./train_set/0/923.jpg
#   inflating: ./train_set/0/928.jpg
#   inflating: ./train_set/0/929.jpg
#   inflating: ./train_set/0/93.jpg
#   inflating: ./train_set/0/930.jpg
#   inflating: ./train_set/0/933.jpg
#   inflating: ./train_set/0/94.jpg
#   inflating: ./train_set/0/947.jpg
#   inflating: ./train_set/0/95.jpg
#   inflating: ./train_set/0/950.jpg
#   inflating: ./train_set/0/956.jpg
#   inflating: ./train_set/0/96.jpg
#   inflating: ./train_set/0/969.jpg
#   inflating: ./train_set/0/970.jpg
#   inflating: ./train_set/0/972.jpg
#   inflating: ./train_set/0/973.jpg
#   inflating: ./train_set/0/978.jpg
#   inflating: ./train_set/0/979.jpg
#   inflating: ./train_set/0/98.jpg
#   inflating: ./train_set/0/980.jpg
#   inflating: ./train_set/0/981.jpg
#   inflating: ./train_set/0/985.jpg
#   inflating: ./train_set/0/987.jpg
#   inflating: ./train_set/0/988.jpg
#   inflating: ./train_set/0/993.jpg
#   inflating: ./train_set/0/996.jpg
#   inflating: ./train_set/0/998.jpg
#    creating: ./train_set/1/
#   inflating: ./train_set/1/0.jpg
#   inflating: ./train_set/1/10.jpg
#   inflating: ./train_set/1/1000.jpg
#   inflating: ./train_set/1/1001.jpg
#   inflating: ./train_set/1/1005.jpg
#   inflating: ./train_set/1/1006.jpg
#   inflating: ./train_set/1/1007.jpg
#   inflating: ./train_set/1/1009.jpg
#   inflating: ./train_set/1/1013.jpg
#   inflating: ./train_set/1/1018.jpg
#   inflating: ./train_set/1/1019.jpg
#   inflating: ./train_set/1/102.jpg
#   inflating: ./train_set/1/1020.jpg
#   inflating: ./train_set/1/1021.jpg
#   inflating: ./train_set/1/1023.jpg
#   inflating: ./train_set/1/1025.jpg
#   inflating: ./train_set/1/1026.jpg
#   inflating: ./train_set/1/1029.jpg
#   inflating: ./train_set/1/103.jpg
#   inflating: ./train_set/1/1030.jpg
#   inflating: ./train_set/1/1034.jpg
#   inflating: ./train_set/1/1036.jpg
#   inflating: ./train_set/1/104.jpg
#   inflating: ./train_set/1/1040.jpg
#   inflating: ./train_set/1/1042.jpg
#   inflating: ./train_set/1/1043.jpg
#   inflating: ./train_set/1/1045.jpg
#   inflating: ./train_set/1/1046.jpg
#   inflating: ./train_set/1/1047.jpg
#   inflating: ./train_set/1/105.jpg
#   inflating: ./train_set/1/1050.jpg
#   inflating: ./train_set/1/1058.jpg
#   inflating: ./train_set/1/1061.jpg
#   inflating: ./train_set/1/1063.jpg
#   inflating: ./train_set/1/1064.jpg
#   inflating: ./train_set/1/1068.jpg
#   inflating: ./train_set/1/1072.jpg
#   inflating: ./train_set/1/1074.jpg
#   inflating: ./train_set/1/1075.jpg
#   inflating: ./train_set/1/1081.jpg
#   inflating: ./train_set/1/1084.jpg
#   inflating: ./train_set/1/1085.jpg
#   inflating: ./train_set/1/1087.jpg
#   inflating: ./train_set/1/1088.jpg
#   inflating: ./train_set/1/1090.jpg
#   inflating: ./train_set/1/1091.jpg
#   inflating: ./train_set/1/1093.jpg
#   inflating: ./train_set/1/1095.jpg
#   inflating: ./train_set/1/1096.jpg
#   inflating: ./train_set/1/1097.jpg
#   inflating: ./train_set/1/1098.jpg
#   inflating: ./train_set/1/1099.jpg
#   inflating: ./train_set/1/11.jpg
#   inflating: ./train_set/1/110.jpg
#   inflating: ./train_set/1/1101.jpg
#   inflating: ./train_set/1/1102.jpg
#   inflating: ./train_set/1/1103.jpg
#   inflating: ./train_set/1/1104.jpg
#   inflating: ./train_set/1/1106.jpg
#   inflating: ./train_set/1/1107.jpg
#   inflating: ./train_set/1/1109.jpg
#   inflating: ./train_set/1/1111.jpg
#   inflating: ./train_set/1/1113.jpg
#   inflating: ./train_set/1/1116.jpg
#   inflating: ./train_set/1/1117.jpg
#   inflating: ./train_set/1/1118.jpg
#   inflating: ./train_set/1/1120.jpg
#   inflating: ./train_set/1/1121.jpg
#   inflating: ./train_set/1/1123.jpg
#   inflating: ./train_set/1/1124.jpg
#   inflating: ./train_set/1/1126.jpg
#   inflating: ./train_set/1/1128.jpg
#   inflating: ./train_set/1/1130.jpg
#   inflating: ./train_set/1/1131.jpg
#   inflating: ./train_set/1/1132.jpg
#   inflating: ./train_set/1/1133.jpg
#   inflating: ./train_set/1/1135.jpg
#   inflating: ./train_set/1/1136.jpg
#   inflating: ./train_set/1/114.jpg
#   inflating: ./train_set/1/1141.jpg
#   inflating: ./train_set/1/1142.jpg
#   inflating: ./train_set/1/1145.jpg
#   inflating: ./train_set/1/1147.jpg
#   inflating: ./train_set/1/1149.jpg
#   inflating: ./train_set/1/115.jpg
#   inflating: ./train_set/1/1152.jpg
#   inflating: ./train_set/1/1153.jpg
#   inflating: ./train_set/1/1156.jpg
#   inflating: ./train_set/1/1157.jpg
#   inflating: ./train_set/1/1158.jpg
#   inflating: ./train_set/1/1159.jpg
#   inflating: ./train_set/1/116.jpg
#   inflating: ./train_set/1/1163.jpg
#   inflating: ./train_set/1/1167.jpg
#   inflating: ./train_set/1/1168.jpg
#   inflating: ./train_set/1/1172.jpg
#   inflating: ./train_set/1/1173.jpg
#   inflating: ./train_set/1/1174.jpg
#   inflating: ./train_set/1/1175.jpg
#   inflating: ./train_set/1/1176.jpg
#   inflating: ./train_set/1/1179.jpg
#   inflating: ./train_set/1/1186.jpg
#   inflating: ./train_set/1/1188.jpg
#   inflating: ./train_set/1/119.jpg
#   inflating: ./train_set/1/1190.jpg
#   inflating: ./train_set/1/1191.jpg
#   inflating: ./train_set/1/1196.jpg
#   inflating: ./train_set/1/1197.jpg
#   inflating: ./train_set/1/1199.jpg
#   inflating: ./train_set/1/12.jpg
#   inflating: ./train_set/1/120.jpg
#   inflating: ./train_set/1/1200.jpg
#   inflating: ./train_set/1/1201.jpg
#   inflating: ./train_set/1/1202.jpg
#   inflating: ./train_set/1/1206.jpg
#   inflating: ./train_set/1/1207.jpg
#   inflating: ./train_set/1/1209.jpg
#   inflating: ./train_set/1/121.jpg
#   inflating: ./train_set/1/1211.jpg
#   inflating: ./train_set/1/1213.jpg
#   inflating: ./train_set/1/1214.jpg
#   inflating: ./train_set/1/1215.jpg
#   inflating: ./train_set/1/122.jpg
#   inflating: ./train_set/1/1220.jpg
#   inflating: ./train_set/1/1222.jpg
#   inflating: ./train_set/1/1224.jpg
#   inflating: ./train_set/1/1225.jpg
#   inflating: ./train_set/1/1226.jpg
#   inflating: ./train_set/1/1227.jpg
#   inflating: ./train_set/1/1229.jpg
#   inflating: ./train_set/1/1230.jpg
#   inflating: ./train_set/1/1231.jpg
#   inflating: ./train_set/1/1236.jpg
#   inflating: ./train_set/1/1237.jpg
#   inflating: ./train_set/1/1238.jpg
#   inflating: ./train_set/1/124.jpg
#   inflating: ./train_set/1/1240.jpg
#   inflating: ./train_set/1/1242.jpg
#   inflating: ./train_set/1/1243.jpg
#   inflating: ./train_set/1/1245.jpg
#   inflating: ./train_set/1/1249.jpg
#   inflating: ./train_set/1/125.jpg
#   inflating: ./train_set/1/1252.jpg
#   inflating: ./train_set/1/1256.jpg
#   inflating: ./train_set/1/1257.jpg
#   inflating: ./train_set/1/1258.jpg
#   inflating: ./train_set/1/1260.jpg
#   inflating: ./train_set/1/1261.jpg
#   inflating: ./train_set/1/1263.jpg
#   inflating: ./train_set/1/1264.jpg
#   inflating: ./train_set/1/1270.jpg
#   inflating: ./train_set/1/1271.jpg
#   inflating: ./train_set/1/1272.jpg
#   inflating: ./train_set/1/1274.jpg
#   inflating: ./train_set/1/1276.jpg
#   inflating: ./train_set/1/1279.jpg
#   inflating: ./train_set/1/1280.jpg
#   inflating: ./train_set/1/1281.jpg
#   inflating: ./train_set/1/1283.jpg
#   inflating: ./train_set/1/1286.jpg
#   inflating: ./train_set/1/1287.jpg
#   inflating: ./train_set/1/1288.jpg
#   inflating: ./train_set/1/1289.jpg
#   inflating: ./train_set/1/1297.jpg
#   inflating: ./train_set/1/1298.jpg
#   inflating: ./train_set/1/1299.jpg
#   inflating: ./train_set/1/130.jpg
#   inflating: ./train_set/1/1300.jpg
#   inflating: ./train_set/1/1302.jpg
#   inflating: ./train_set/1/1303.jpg
#   inflating: ./train_set/1/1304.jpg
#   inflating: ./train_set/1/1306.jpg
#   inflating: ./train_set/1/1307.jpg
#   inflating: ./train_set/1/1310.jpg
#   inflating: ./train_set/1/1311.jpg
#   inflating: ./train_set/1/1313.jpg
#   inflating: ./train_set/1/1315.jpg
#   inflating: ./train_set/1/1316.jpg
#   inflating: ./train_set/1/1317.jpg
#   inflating: ./train_set/1/1318.jpg
#   inflating: ./train_set/1/132.jpg
#   inflating: ./train_set/1/1320.jpg
#   inflating: ./train_set/1/1321.jpg
#   inflating: ./train_set/1/1324.jpg
#   inflating: ./train_set/1/1327.jpg
#   inflating: ./train_set/1/1328.jpg
#   inflating: ./train_set/1/1329.jpg
#   inflating: ./train_set/1/133.jpg
#   inflating: ./train_set/1/1330.jpg
#   inflating: ./train_set/1/1331.jpg
#   inflating: ./train_set/1/1332.jpg
#   inflating: ./train_set/1/1337.jpg
#   inflating: ./train_set/1/1339.jpg
#   inflating: ./train_set/1/134.jpg
#   inflating: ./train_set/1/1341.jpg
#   inflating: ./train_set/1/1343.jpg
#   inflating: ./train_set/1/1344.jpg
#   inflating: ./train_set/1/135.jpg
#   inflating: ./train_set/1/1353.jpg
#   inflating: ./train_set/1/1357.jpg
#   inflating: ./train_set/1/1359.jpg
#   inflating: ./train_set/1/136.jpg
#   inflating: ./train_set/1/1360.jpg
#   inflating: ./train_set/1/1361.jpg
#   inflating: ./train_set/1/1362.jpg
#   inflating: ./train_set/1/1365.jpg
#   inflating: ./train_set/1/1367.jpg
#   inflating: ./train_set/1/1368.jpg
#   inflating: ./train_set/1/1369.jpg
#   inflating: ./train_set/1/137.jpg
#   inflating: ./train_set/1/1370.jpg
#   inflating: ./train_set/1/1374.jpg
#   inflating: ./train_set/1/1376.jpg
#   inflating: ./train_set/1/1377.jpg
#   inflating: ./train_set/1/1378.jpg
#   inflating: ./train_set/1/1380.jpg
#   inflating: ./train_set/1/1386.jpg
#   inflating: ./train_set/1/1387.jpg
#   inflating: ./train_set/1/1389.jpg
#   inflating: ./train_set/1/139.jpg
#   inflating: ./train_set/1/1390.jpg
#   inflating: ./train_set/1/1391.jpg
#   inflating: ./train_set/1/1392.jpg
#   inflating: ./train_set/1/1394.jpg
#   inflating: ./train_set/1/1396.jpg
#   inflating: ./train_set/1/1399.jpg
#   inflating: ./train_set/1/1401.jpg
#   inflating: ./train_set/1/1404.jpg
#   inflating: ./train_set/1/1405.jpg
#   inflating: ./train_set/1/1407.jpg
#   inflating: ./train_set/1/1409.jpg
#   inflating: ./train_set/1/141.jpg
#   inflating: ./train_set/1/1413.jpg
#   inflating: ./train_set/1/1419.jpg
#   inflating: ./train_set/1/142.jpg
#   inflating: ./train_set/1/1420.jpg
#   inflating: ./train_set/1/1421.jpg
#   inflating: ./train_set/1/1425.jpg
#   inflating: ./train_set/1/1427.jpg
#   inflating: ./train_set/1/1428.jpg
#   inflating: ./train_set/1/1429.jpg
#   inflating: ./train_set/1/143.jpg
#   inflating: ./train_set/1/1430.jpg
#   inflating: ./train_set/1/1432.jpg
#   inflating: ./train_set/1/1436.jpg
#   inflating: ./train_set/1/1439.jpg
#   inflating: ./train_set/1/144.jpg
#   inflating: ./train_set/1/1441.jpg
#   inflating: ./train_set/1/1442.jpg
#   inflating: ./train_set/1/1443.jpg
#   inflating: ./train_set/1/1445.jpg
#   inflating: ./train_set/1/1447.jpg
#   inflating: ./train_set/1/145.jpg
#   inflating: ./train_set/1/1454.jpg
#   inflating: ./train_set/1/1457.jpg
#   inflating: ./train_set/1/1459.jpg
#   inflating: ./train_set/1/146.jpg
#   inflating: ./train_set/1/1460.jpg
#   inflating: ./train_set/1/1461.jpg
#   inflating: ./train_set/1/1463.jpg
#   inflating: ./train_set/1/1465.jpg
#   inflating: ./train_set/1/1466.jpg
#   inflating: ./train_set/1/1467.jpg
#   inflating: ./train_set/1/1468.jpg
#   inflating: ./train_set/1/147.jpg
#   inflating: ./train_set/1/1470.jpg
#   inflating: ./train_set/1/1471.jpg
#   inflating: ./train_set/1/1473.jpg
#   inflating: ./train_set/1/1475.jpg
#   inflating: ./train_set/1/1476.jpg
#   inflating: ./train_set/1/148.jpg
#   inflating: ./train_set/1/1480.jpg
#   inflating: ./train_set/1/1481.jpg
#   inflating: ./train_set/1/1483.jpg
#   inflating: ./train_set/1/1484.jpg
#   inflating: ./train_set/1/1485.jpg
#   inflating: ./train_set/1/1487.jpg
#   inflating: ./train_set/1/1488.jpg
#   inflating: ./train_set/1/1489.jpg
#   inflating: ./train_set/1/1491.jpg
#   inflating: ./train_set/1/1498.jpg
#   inflating: ./train_set/1/1499.jpg
#   inflating: ./train_set/1/15.jpg
#   inflating: ./train_set/1/1502.jpg
#   inflating: ./train_set/1/1505.jpg
#   inflating: ./train_set/1/1508.jpg
#   inflating: ./train_set/1/1510.jpg
#   inflating: ./train_set/1/1511.jpg
#   inflating: ./train_set/1/1517.jpg
#   inflating: ./train_set/1/1522.jpg
#   inflating: ./train_set/1/1523.jpg
#   inflating: ./train_set/1/1524.jpg
#   inflating: ./train_set/1/1525.jpg
#   inflating: ./train_set/1/1527.jpg
#   inflating: ./train_set/1/1534.jpg
#   inflating: ./train_set/1/1537.jpg
#   inflating: ./train_set/1/1539.jpg
#   inflating: ./train_set/1/1540.jpg
#   inflating: ./train_set/1/1541.jpg
#   inflating: ./train_set/1/1545.jpg
#   inflating: ./train_set/1/155.jpg
#   inflating: ./train_set/1/1554.jpg
#   inflating: ./train_set/1/1556.jpg
#   inflating: ./train_set/1/1557.jpg
#   inflating: ./train_set/1/1558.jpg
#   inflating: ./train_set/1/156.jpg
#   inflating: ./train_set/1/1562.jpg
#   inflating: ./train_set/1/1563.jpg
#   inflating: ./train_set/1/1567.jpg
#   inflating: ./train_set/1/1569.jpg
#   inflating: ./train_set/1/157.jpg
#   inflating: ./train_set/1/1573.jpg
#   inflating: ./train_set/1/1574.jpg
#   inflating: ./train_set/1/1576.jpg
#   inflating: ./train_set/1/1578.jpg
#   inflating: ./train_set/1/1579.jpg
#   inflating: ./train_set/1/158.jpg
#   inflating: ./train_set/1/1583.jpg
#   inflating: ./train_set/1/1584.jpg
#   inflating: ./train_set/1/1586.jpg
#   inflating: ./train_set/1/1587.jpg
#   inflating: ./train_set/1/1589.jpg
#   inflating: ./train_set/1/159.jpg
#   inflating: ./train_set/1/1593.jpg
#   inflating: ./train_set/1/1598.jpg
#   inflating: ./train_set/1/1599.jpg
#   inflating: ./train_set/1/1605.jpg
#   inflating: ./train_set/1/1606.jpg
#   inflating: ./train_set/1/1607.jpg
#   inflating: ./train_set/1/1608.jpg
#   inflating: ./train_set/1/1609.jpg
#   inflating: ./train_set/1/1612.jpg
#   inflating: ./train_set/1/1613.jpg
#   inflating: ./train_set/1/1614.jpg
#   inflating: ./train_set/1/1617.jpg
#   inflating: ./train_set/1/1619.jpg
#   inflating: ./train_set/1/162.jpg
#   inflating: ./train_set/1/1622.jpg
#   inflating: ./train_set/1/1629.jpg
#   inflating: ./train_set/1/1630.jpg
#   inflating: ./train_set/1/1632.jpg
#   inflating: ./train_set/1/1633.jpg
#   inflating: ./train_set/1/1636.jpg
#   inflating: ./train_set/1/1637.jpg
#   inflating: ./train_set/1/1638.jpg
#   inflating: ./train_set/1/164.jpg
#   inflating: ./train_set/1/1641.jpg
#   inflating: ./train_set/1/1643.jpg
#   inflating: ./train_set/1/1644.jpg
#   inflating: ./train_set/1/1645.jpg
#   inflating: ./train_set/1/1646.jpg
#   inflating: ./train_set/1/1649.jpg
#   inflating: ./train_set/1/1651.jpg
#   inflating: ./train_set/1/1658.jpg
#   inflating: ./train_set/1/166.jpg
#   inflating: ./train_set/1/1660.jpg
#   inflating: ./train_set/1/1664.jpg
#   inflating: ./train_set/1/1665.jpg
#   inflating: ./train_set/1/1669.jpg
#   inflating: ./train_set/1/167.jpg
#   inflating: ./train_set/1/1673.jpg
#   inflating: ./train_set/1/1677.jpg
#   inflating: ./train_set/1/1678.jpg
#   inflating: ./train_set/1/1679.jpg
#   inflating: ./train_set/1/1681.jpg
#   inflating: ./train_set/1/1682.jpg
#   inflating: ./train_set/1/1683.jpg
#   inflating: ./train_set/1/1684.jpg
#   inflating: ./train_set/1/1685.jpg
#   inflating: ./train_set/1/1686.jpg
#   inflating: ./train_set/1/1690.jpg
#   inflating: ./train_set/1/1691.jpg
#   inflating: ./train_set/1/1694.jpg
#   inflating: ./train_set/1/1696.jpg
#   inflating: ./train_set/1/1702.jpg
#   inflating: ./train_set/1/1703.jpg
#   inflating: ./train_set/1/1708.jpg
#   inflating: ./train_set/1/1709.jpg
#   inflating: ./train_set/1/172.jpg
#   inflating: ./train_set/1/173.jpg
#   inflating: ./train_set/1/174.jpg
#   inflating: ./train_set/1/175.jpg
#   inflating: ./train_set/1/176.jpg
#   inflating: ./train_set/1/177.jpg
#   inflating: ./train_set/1/178.jpg
#   inflating: ./train_set/1/179.jpg
#   inflating: ./train_set/1/181.jpg
#   inflating: ./train_set/1/184.jpg
#   inflating: ./train_set/1/186.jpg
#   inflating: ./train_set/1/188.jpg
#   inflating: ./train_set/1/189.jpg
#   inflating: ./train_set/1/19.jpg
#   inflating: ./train_set/1/190.jpg
#   inflating: ./train_set/1/194.jpg
#   inflating: ./train_set/1/196.jpg
#   inflating: ./train_set/1/198.jpg
#   inflating: ./train_set/1/2.jpg
#   inflating: ./train_set/1/202.jpg
#   inflating: ./train_set/1/204.jpg
#   inflating: ./train_set/1/205.jpg
#   inflating: ./train_set/1/206.jpg
#   inflating: ./train_set/1/207.jpg
#   inflating: ./train_set/1/21.jpg
#   inflating: ./train_set/1/210.jpg
#   inflating: ./train_set/1/211.jpg
#   inflating: ./train_set/1/213.jpg
#   inflating: ./train_set/1/215.jpg
#   inflating: ./train_set/1/216.jpg
#   inflating: ./train_set/1/218.jpg
#   inflating: ./train_set/1/219.jpg
#   inflating: ./train_set/1/221.jpg
#   inflating: ./train_set/1/225.jpg
#   inflating: ./train_set/1/226.jpg
#   inflating: ./train_set/1/227.jpg
#   inflating: ./train_set/1/23.jpg
#   inflating: ./train_set/1/234.jpg
#   inflating: ./train_set/1/235.jpg
#   inflating: ./train_set/1/238.jpg
#   inflating: ./train_set/1/241.jpg
#   inflating: ./train_set/1/243.jpg
#   inflating: ./train_set/1/245.jpg
#   inflating: ./train_set/1/247.jpg
#   inflating: ./train_set/1/249.jpg
#   inflating: ./train_set/1/25.jpg
#   inflating: ./train_set/1/254.jpg
#   inflating: ./train_set/1/255.jpg
#   inflating: ./train_set/1/257.jpg
#   inflating: ./train_set/1/263.jpg
#   inflating: ./train_set/1/265.jpg
#   inflating: ./train_set/1/268.jpg
#   inflating: ./train_set/1/27.jpg
#   inflating: ./train_set/1/270.jpg
#   inflating: ./train_set/1/272.jpg
#   inflating: ./train_set/1/273.jpg
#   inflating: ./train_set/1/276.jpg
#   inflating: ./train_set/1/278.jpg
#   inflating: ./train_set/1/279.jpg
#   inflating: ./train_set/1/281.jpg
#   inflating: ./train_set/1/282.jpg
#   inflating: ./train_set/1/283.jpg
#   inflating: ./train_set/1/285.jpg
#   inflating: ./train_set/1/286.jpg
#   inflating: ./train_set/1/289.jpg
#   inflating: ./train_set/1/290.jpg
#   inflating: ./train_set/1/291.jpg
#   inflating: ./train_set/1/293.jpg
#   inflating: ./train_set/1/299.jpg
#   inflating: ./train_set/1/302.jpg
#   inflating: ./train_set/1/304.jpg
#   inflating: ./train_set/1/318.jpg
#   inflating: ./train_set/1/321.jpg
#   inflating: ./train_set/1/322.jpg
#   inflating: ./train_set/1/323.jpg
#   inflating: ./train_set/1/324.jpg
#   inflating: ./train_set/1/325.jpg
#   inflating: ./train_set/1/326.jpg
#   inflating: ./train_set/1/327.jpg
#   inflating: ./train_set/1/33.jpg
#   inflating: ./train_set/1/333.jpg
#   inflating: ./train_set/1/335.jpg
#   inflating: ./train_set/1/337.jpg
#   inflating: ./train_set/1/340.jpg
#   inflating: ./train_set/1/342.jpg
#   inflating: ./train_set/1/345.jpg
#   inflating: ./train_set/1/347.jpg
#   inflating: ./train_set/1/348.jpg
#   inflating: ./train_set/1/353.jpg
#   inflating: ./train_set/1/356.jpg
#   inflating: ./train_set/1/358.jpg
#   inflating: ./train_set/1/359.jpg
#   inflating: ./train_set/1/36.jpg
#   inflating: ./train_set/1/361.jpg
#   inflating: ./train_set/1/362.jpg
#   inflating: ./train_set/1/363.jpg
#   inflating: ./train_set/1/364.jpg
#   inflating: ./train_set/1/365.jpg
#   inflating: ./train_set/1/367.jpg
#   inflating: ./train_set/1/376.jpg
#   inflating: ./train_set/1/38.jpg
#   inflating: ./train_set/1/381.jpg
#   inflating: ./train_set/1/384.jpg
#   inflating: ./train_set/1/385.jpg
#   inflating: ./train_set/1/386.jpg
#   inflating: ./train_set/1/387.jpg
#   inflating: ./train_set/1/388.jpg
#   inflating: ./train_set/1/389.jpg
#   inflating: ./train_set/1/39.jpg
#   inflating: ./train_set/1/390.jpg
#   inflating: ./train_set/1/391.jpg
#   inflating: ./train_set/1/392.jpg
#   inflating: ./train_set/1/399.jpg
#   inflating: ./train_set/1/4.jpg
#   inflating: ./train_set/1/401.jpg
#   inflating: ./train_set/1/403.jpg
#   inflating: ./train_set/1/404.jpg
#   inflating: ./train_set/1/407.jpg
#   inflating: ./train_set/1/408.jpg
#   inflating: ./train_set/1/410.jpg
#   inflating: ./train_set/1/411.jpg
#   inflating: ./train_set/1/414.jpg
#   inflating: ./train_set/1/415.jpg
#   inflating: ./train_set/1/416.jpg
#   inflating: ./train_set/1/417.jpg
#   inflating: ./train_set/1/418.jpg
#   inflating: ./train_set/1/420.jpg
#   inflating: ./train_set/1/421.jpg
#   inflating: ./train_set/1/424.jpg
#   inflating: ./train_set/1/428.jpg
#   inflating: ./train_set/1/43.jpg
#   inflating: ./train_set/1/431.jpg
#   inflating: ./train_set/1/435.jpg
#   inflating: ./train_set/1/436.jpg
#   inflating: ./train_set/1/437.jpg
#   inflating: ./train_set/1/439.jpg
#   inflating: ./train_set/1/44.jpg
#   inflating: ./train_set/1/440.jpg
#   inflating: ./train_set/1/441.jpg
#   inflating: ./train_set/1/444.jpg
#   inflating: ./train_set/1/445.jpg
#   inflating: ./train_set/1/447.jpg
#   inflating: ./train_set/1/448.jpg
#   inflating: ./train_set/1/45.jpg
#   inflating: ./train_set/1/453.jpg
#   inflating: ./train_set/1/456.jpg
#   inflating: ./train_set/1/457.jpg
#   inflating: ./train_set/1/459.jpg
#   inflating: ./train_set/1/460.jpg
#   inflating: ./train_set/1/462.jpg
#   inflating: ./train_set/1/463.jpg
#   inflating: ./train_set/1/464.jpg
#   inflating: ./train_set/1/465.jpg
#   inflating: ./train_set/1/466.jpg
#   inflating: ./train_set/1/467.jpg
#   inflating: ./train_set/1/47.jpg
#   inflating: ./train_set/1/471.jpg
#   inflating: ./train_set/1/472.jpg
#   inflating: ./train_set/1/473.jpg
#   inflating: ./train_set/1/479.jpg
#   inflating: ./train_set/1/480.jpg
#   inflating: ./train_set/1/481.jpg
#   inflating: ./train_set/1/483.jpg
#   inflating: ./train_set/1/485.jpg
#   inflating: ./train_set/1/486.jpg
#   inflating: ./train_set/1/488.jpg
#   inflating: ./train_set/1/497.jpg
#   inflating: ./train_set/1/498.jpg
#   inflating: ./train_set/1/500.jpg
#   inflating: ./train_set/1/501.jpg
#   inflating: ./train_set/1/502.jpg
#   inflating: ./train_set/1/504.jpg
#   inflating: ./train_set/1/506.jpg
#   inflating: ./train_set/1/507.jpg
#   inflating: ./train_set/1/509.jpg
#   inflating: ./train_set/1/51.jpg
#   inflating: ./train_set/1/510.jpg
#   inflating: ./train_set/1/511.jpg
#   inflating: ./train_set/1/512.jpg
#   inflating: ./train_set/1/513.jpg
#   inflating: ./train_set/1/515.jpg
#   inflating: ./train_set/1/517.jpg
#   inflating: ./train_set/1/518.jpg
#   inflating: ./train_set/1/519.jpg
#   inflating: ./train_set/1/522.jpg
#   inflating: ./train_set/1/524.jpg
#   inflating: ./train_set/1/525.jpg
#   inflating: ./train_set/1/526.jpg
#   inflating: ./train_set/1/527.jpg
#   inflating: ./train_set/1/529.jpg
#   inflating: ./train_set/1/530.jpg
#   inflating: ./train_set/1/532.jpg
#   inflating: ./train_set/1/533.jpg
#   inflating: ./train_set/1/536.jpg
#   inflating: ./train_set/1/537.jpg
#   inflating: ./train_set/1/539.jpg
#   inflating: ./train_set/1/543.jpg
#   inflating: ./train_set/1/544.jpg
#   inflating: ./train_set/1/547.jpg
#   inflating: ./train_set/1/548.jpg
#   inflating: ./train_set/1/550.jpg
#   inflating: ./train_set/1/552.jpg
#   inflating: ./train_set/1/553.jpg
#   inflating: ./train_set/1/556.jpg
#   inflating: ./train_set/1/558.jpg
#   inflating: ./train_set/1/559.jpg
#   inflating: ./train_set/1/56.jpg
#   inflating: ./train_set/1/562.jpg
#   inflating: ./train_set/1/563.jpg
#   inflating: ./train_set/1/564.jpg
#   inflating: ./train_set/1/565.jpg
#   inflating: ./train_set/1/57.jpg
#   inflating: ./train_set/1/570.jpg
#   inflating: ./train_set/1/571.jpg
#   inflating: ./train_set/1/572.jpg
#   inflating: ./train_set/1/573.jpg
#   inflating: ./train_set/1/574.jpg
#   inflating: ./train_set/1/577.jpg
#   inflating: ./train_set/1/585.jpg
#   inflating: ./train_set/1/586.jpg
#   inflating: ./train_set/1/591.jpg
#   inflating: ./train_set/1/592.jpg
#   inflating: ./train_set/1/594.jpg
#   inflating: ./train_set/1/595.jpg
#   inflating: ./train_set/1/596.jpg
#   inflating: ./train_set/1/598.jpg
#   inflating: ./train_set/1/60.jpg
#   inflating: ./train_set/1/603.jpg
#   inflating: ./train_set/1/604.jpg
#   inflating: ./train_set/1/605.jpg
#   inflating: ./train_set/1/609.jpg
#   inflating: ./train_set/1/611.jpg
#   inflating: ./train_set/1/613.jpg
#   inflating: ./train_set/1/617.jpg
#   inflating: ./train_set/1/619.jpg
#   inflating: ./train_set/1/620.jpg
#   inflating: ./train_set/1/622.jpg
#   inflating: ./train_set/1/623.jpg
#   inflating: ./train_set/1/624.jpg
#   inflating: ./train_set/1/626.jpg
#   inflating: ./train_set/1/629.jpg
#   inflating: ./train_set/1/631.jpg
#   inflating: ./train_set/1/634.jpg
#   inflating: ./train_set/1/638.jpg
#   inflating: ./train_set/1/640.jpg
#   inflating: ./train_set/1/644.jpg
#   inflating: ./train_set/1/646.jpg
#   inflating: ./train_set/1/649.jpg
#   inflating: ./train_set/1/65.jpg
#   inflating: ./train_set/1/650.jpg
#   inflating: ./train_set/1/651.jpg
#   inflating: ./train_set/1/652.jpg
#   inflating: ./train_set/1/653.jpg
#   inflating: ./train_set/1/654.jpg
#   inflating: ./train_set/1/655.jpg
#   inflating: ./train_set/1/656.jpg
#   inflating: ./train_set/1/657.jpg
#   inflating: ./train_set/1/659.jpg
#   inflating: ./train_set/1/66.jpg
#   inflating: ./train_set/1/662.jpg
#   inflating: ./train_set/1/665.jpg
#   inflating: ./train_set/1/666.jpg
#   inflating: ./train_set/1/668.jpg
#   inflating: ./train_set/1/676.jpg
#   inflating: ./train_set/1/682.jpg
#   inflating: ./train_set/1/683.jpg
#   inflating: ./train_set/1/688.jpg
#   inflating: ./train_set/1/69.jpg
#   inflating: ./train_set/1/693.jpg
#   inflating: ./train_set/1/694.jpg
#   inflating: ./train_set/1/695.jpg
#   inflating: ./train_set/1/697.jpg
#   inflating: ./train_set/1/700.jpg
#   inflating: ./train_set/1/701.jpg
#   inflating: ./train_set/1/702.jpg
#   inflating: ./train_set/1/704.jpg
#   inflating: ./train_set/1/705.jpg
#   inflating: ./train_set/1/708.jpg
#   inflating: ./train_set/1/710.jpg
#   inflating: ./train_set/1/712.jpg
#   inflating: ./train_set/1/713.jpg
#   inflating: ./train_set/1/715.jpg
#   inflating: ./train_set/1/717.jpg
#   inflating: ./train_set/1/718.jpg
#   inflating: ./train_set/1/722.jpg
#   inflating: ./train_set/1/723.jpg
#   inflating: ./train_set/1/725.jpg
#   inflating: ./train_set/1/726.jpg
#   inflating: ./train_set/1/727.jpg
#   inflating: ./train_set/1/73.jpg
#   inflating: ./train_set/1/731.jpg
#   inflating: ./train_set/1/732.jpg
#   inflating: ./train_set/1/733.jpg
#   inflating: ./train_set/1/734.jpg
#   inflating: ./train_set/1/735.jpg
#   inflating: ./train_set/1/737.jpg
#   inflating: ./train_set/1/739.jpg
#   inflating: ./train_set/1/74.jpg
#   inflating: ./train_set/1/740.jpg
#   inflating: ./train_set/1/742.jpg
#   inflating: ./train_set/1/744.jpg
#   inflating: ./train_set/1/746.jpg
#   inflating: ./train_set/1/748.jpg
#   inflating: ./train_set/1/75.jpg
#   inflating: ./train_set/1/751.jpg
#   inflating: ./train_set/1/752.jpg
#   inflating: ./train_set/1/754.jpg
#   inflating: ./train_set/1/759.jpg
#   inflating: ./train_set/1/76.jpg
#   inflating: ./train_set/1/762.jpg
#   inflating: ./train_set/1/765.jpg
#   inflating: ./train_set/1/773.jpg
#   inflating: ./train_set/1/774.jpg
#   inflating: ./train_set/1/775.jpg
#   inflating: ./train_set/1/779.jpg
#   inflating: ./train_set/1/782.jpg
#   inflating: ./train_set/1/783.jpg
#   inflating: ./train_set/1/785.jpg
#   inflating: ./train_set/1/787.jpg
#   inflating: ./train_set/1/788.jpg
#   inflating: ./train_set/1/789.jpg
#   inflating: ./train_set/1/794.jpg
#   inflating: ./train_set/1/797.jpg
#   inflating: ./train_set/1/799.jpg
#   inflating: ./train_set/1/8.jpg
#   inflating: ./train_set/1/800.jpg
#   inflating: ./train_set/1/802.jpg
#   inflating: ./train_set/1/803.jpg
#   inflating: ./train_set/1/804.jpg
#   inflating: ./train_set/1/807.jpg
#   inflating: ./train_set/1/808.jpg
#   inflating: ./train_set/1/81.jpg
#   inflating: ./train_set/1/810.jpg
#   inflating: ./train_set/1/811.jpg
#   inflating: ./train_set/1/813.jpg
#   inflating: ./train_set/1/814.jpg
#   inflating: ./train_set/1/817.jpg
#   inflating: ./train_set/1/818.jpg
#   inflating: ./train_set/1/820.jpg
#   inflating: ./train_set/1/822.jpg
#   inflating: ./train_set/1/824.jpg
#   inflating: ./train_set/1/827.jpg
#   inflating: ./train_set/1/830.jpg
#   inflating: ./train_set/1/831.jpg
#   inflating: ./train_set/1/832.jpg
#   inflating: ./train_set/1/833.jpg
#   inflating: ./train_set/1/835.jpg
#   inflating: ./train_set/1/837.jpg
#   inflating: ./train_set/1/838.jpg
#   inflating: ./train_set/1/839.jpg
#   inflating: ./train_set/1/841.jpg
#   inflating: ./train_set/1/845.jpg
#   inflating: ./train_set/1/848.jpg
#   inflating: ./train_set/1/849.jpg
#   inflating: ./train_set/1/850.jpg
#   inflating: ./train_set/1/857.jpg
#   inflating: ./train_set/1/858.jpg
#   inflating: ./train_set/1/859.jpg
#   inflating: ./train_set/1/86.jpg
#   inflating: ./train_set/1/863.jpg
#   inflating: ./train_set/1/864.jpg
#   inflating: ./train_set/1/867.jpg
#   inflating: ./train_set/1/869.jpg
#   inflating: ./train_set/1/870.jpg
#   inflating: ./train_set/1/871.jpg
#   inflating: ./train_set/1/875.jpg
#   inflating: ./train_set/1/880.jpg
#   inflating: ./train_set/1/881.jpg
#   inflating: ./train_set/1/884.jpg
#   inflating: ./train_set/1/885.jpg
#   inflating: ./train_set/1/888.jpg
#   inflating: ./train_set/1/89.jpg
#   inflating: ./train_set/1/893.jpg
#   inflating: ./train_set/1/898.jpg
#   inflating: ./train_set/1/900.jpg
#   inflating: ./train_set/1/901.jpg
#   inflating: ./train_set/1/902.jpg
#   inflating: ./train_set/1/905.jpg
#   inflating: ./train_set/1/906.jpg
#   inflating: ./train_set/1/908.jpg
#   inflating: ./train_set/1/910.jpg
#   inflating: ./train_set/1/911.jpg
#   inflating: ./train_set/1/917.jpg
#   inflating: ./train_set/1/92.jpg
#   inflating: ./train_set/1/921.jpg
#   inflating: ./train_set/1/925.jpg
#   inflating: ./train_set/1/931.jpg
#   inflating: ./train_set/1/932.jpg
#   inflating: ./train_set/1/934.jpg
#   inflating: ./train_set/1/936.jpg
#   inflating: ./train_set/1/939.jpg
#   inflating: ./train_set/1/940.jpg
#   inflating: ./train_set/1/942.jpg
#   inflating: ./train_set/1/943.jpg
#   inflating: ./train_set/1/944.jpg
#   inflating: ./train_set/1/945.jpg
#   inflating: ./train_set/1/946.jpg
#   inflating: ./train_set/1/948.jpg
#   inflating: ./train_set/1/949.jpg
#   inflating: ./train_set/1/951.jpg
#   inflating: ./train_set/1/953.jpg
#   inflating: ./train_set/1/954.jpg
#   inflating: ./train_set/1/955.jpg
#   inflating: ./train_set/1/957.jpg
#   inflating: ./train_set/1/958.jpg
#   inflating: ./train_set/1/959.jpg
#   inflating: ./train_set/1/961.jpg
#   inflating: ./train_set/1/962.jpg
#   inflating: ./train_set/1/965.jpg
#   inflating: ./train_set/1/966.jpg
#   inflating: ./train_set/1/967.jpg
#   inflating: ./train_set/1/968.jpg
#   inflating: ./train_set/1/974.jpg
#   inflating: ./train_set/1/977.jpg
#   inflating: ./train_set/1/982.jpg
#   inflating: ./train_set/1/984.jpg
#   inflating: ./train_set/1/986.jpg
#   inflating: ./train_set/1/99.jpg
#   inflating: ./train_set/1/990.jpg
#   inflating: ./train_set/1/992.jpg
#   inflating: ./train_set/1/995.jpg
#   inflating: ./train_set/1/997.jpg
#    creating: ./train_set/2/
#   inflating: ./train_set/2/10007.jpg
#   inflating: ./train_set/2/10039.jpg
#   inflating: ./train_set/2/10058.jpg
#   inflating: ./train_set/2/10099.jpg
#   inflating: ./train_set/2/10108.jpg
#   inflating: ./train_set/2/10133.jpg
#   inflating: ./train_set/2/10137.jpg
#   inflating: ./train_set/2/10143.jpg
#   inflating: ./train_set/2/10161.jpg
#   inflating: ./train_set/2/10210.jpg
#   inflating: ./train_set/2/10223.jpg
#   inflating: ./train_set/2/10226.jpg
#   inflating: ./train_set/2/10273.jpg
#   inflating: ./train_set/2/10304.jpg
#   inflating: ./train_set/2/10334.jpg
#   inflating: ./train_set/2/10357.jpg
#   inflating: ./train_set/2/10390.jpg
#   inflating: ./train_set/2/10401.jpg
#   inflating: ./train_set/2/10416.jpg
#   inflating: ./train_set/2/10418.jpg
#   inflating: ./train_set/2/10427.jpg
#   inflating: ./train_set/2/10494.jpg
#   inflating: ./train_set/2/10512.jpg
#   inflating: ./train_set/2/10520.jpg
#   inflating: ./train_set/2/10535.jpg
#   inflating: ./train_set/2/10542.jpg
#   inflating: ./train_set/2/10568.jpg
#   inflating: ./train_set/2/1057.jpg
#   inflating: ./train_set/2/10586.jpg
#   inflating: ./train_set/2/10598.jpg
#   inflating: ./train_set/2/10601.jpg
#   inflating: ./train_set/2/10625.jpg
#   inflating: ./train_set/2/10630.jpg
#   inflating: ./train_set/2/10638.jpg
#   inflating: ./train_set/2/10750.jpg
#   inflating: ./train_set/2/10752.jpg
#   inflating: ./train_set/2/1076.jpg
#   inflating: ./train_set/2/10768.jpg
#   inflating: ./train_set/2/10845.jpg
#   inflating: ./train_set/2/10881.jpg
#   inflating: ./train_set/2/10906.jpg
#   inflating: ./train_set/2/10928.jpg
#   inflating: ./train_set/2/10936.jpg
#   inflating: ./train_set/2/10968.jpg
#   inflating: ./train_set/2/10977.jpg
#   inflating: ./train_set/2/10992.jpg
#   inflating: ./train_set/2/11081.jpg
#   inflating: ./train_set/2/1112.jpg
#   inflating: ./train_set/2/11136.jpg
#   inflating: ./train_set/2/11153.jpg
#   inflating: ./train_set/2/1119.jpg
#   inflating: ./train_set/2/11217.jpg
#   inflating: ./train_set/2/11220.jpg
#   inflating: ./train_set/2/11222.jpg
#   inflating: ./train_set/2/11238.jpg
#   inflating: ./train_set/2/1125.jpg
#   inflating: ./train_set/2/11252.jpg
#   inflating: ./train_set/2/11265.jpg
#   inflating: ./train_set/2/11287.jpg
#   inflating: ./train_set/2/11298.jpg
#   inflating: ./train_set/2/11319.jpg
#   inflating: ./train_set/2/11324.jpg
#   inflating: ./train_set/2/11336.jpg
#   inflating: ./train_set/2/11351.jpg
#   inflating: ./train_set/2/11379.jpg
#   inflating: ./train_set/2/11404.jpg
#   inflating: ./train_set/2/11430.jpg
#   inflating: ./train_set/2/11436.jpg
#   inflating: ./train_set/2/11445.jpg
#   inflating: ./train_set/2/11530.jpg
#   inflating: ./train_set/2/11602.jpg
#   inflating: ./train_set/2/11605.jpg
#   inflating: ./train_set/2/11615.jpg
#   inflating: ./train_set/2/11625.jpg
#   inflating: ./train_set/2/11630.jpg
#   inflating: ./train_set/2/11633.jpg
#   inflating: ./train_set/2/1165.jpg
#   inflating: ./train_set/2/11654.jpg
#   inflating: ./train_set/2/11663.jpg
#   inflating: ./train_set/2/11675.jpg
#   inflating: ./train_set/2/11810.jpg
#   inflating: ./train_set/2/11819.jpg
#   inflating: ./train_set/2/11889.jpg
#   inflating: ./train_set/2/11891.jpg
#   inflating: ./train_set/2/11916.jpg
#   inflating: ./train_set/2/1193.jpg
#   inflating: ./train_set/2/11935.jpg
#   inflating: ./train_set/2/11948.jpg
#   inflating: ./train_set/2/12005.jpg
#   inflating: ./train_set/2/12036.jpg
#   inflating: ./train_set/2/12097.jpg
#   inflating: ./train_set/2/12128.jpg
#   inflating: ./train_set/2/12148.jpg
#   inflating: ./train_set/2/12157.jpg
#   inflating: ./train_set/2/1217.jpg
#   inflating: ./train_set/2/12218.jpg
#   inflating: ./train_set/2/12304.jpg
#   inflating: ./train_set/2/12325.jpg
#   inflating: ./train_set/2/12337.jpg
#   inflating: ./train_set/2/12338.jpg
#   inflating: ./train_set/2/12364.jpg
#   inflating: ./train_set/2/12370.jpg
#   inflating: ./train_set/2/12373.jpg
#   inflating: ./train_set/2/12375.jpg
#   inflating: ./train_set/2/12461.jpg
#   inflating: ./train_set/2/12510.jpg
#   inflating: ./train_set/2/12529.jpg
#   inflating: ./train_set/2/12546.jpg
#   inflating: ./train_set/2/12547.jpg
#   inflating: ./train_set/2/12558.jpg
#   inflating: ./train_set/2/12594.jpg
#   inflating: ./train_set/2/12610.jpg
#   inflating: ./train_set/2/12666.jpg
#   inflating: ./train_set/2/1269.jpg
#   inflating: ./train_set/2/12696.jpg
#   inflating: ./train_set/2/12724.jpg
#   inflating: ./train_set/2/12730.jpg
#   inflating: ./train_set/2/12738.jpg
#   inflating: ./train_set/2/12790.jpg
#   inflating: ./train_set/2/12885.jpg
#   inflating: ./train_set/2/12892.jpg
#   inflating: ./train_set/2/12918.jpg
#   inflating: ./train_set/2/1296.jpg
#   inflating: ./train_set/2/12974.jpg
#   inflating: ./train_set/2/1301.jpg
#   inflating: ./train_set/2/13013.jpg
#   inflating: ./train_set/2/13021.jpg
#   inflating: ./train_set/2/1309.jpg
#   inflating: ./train_set/2/131.jpg
#   inflating: ./train_set/2/13105.jpg
#   inflating: ./train_set/2/13145.jpg
#   inflating: ./train_set/2/13152.jpg
#   inflating: ./train_set/2/13162.jpg
#   inflating: ./train_set/2/13186.jpg
#   inflating: ./train_set/2/13189.jpg
#   inflating: ./train_set/2/13192.jpg
#   inflating: ./train_set/2/13206.jpg
#   inflating: ./train_set/2/13223.jpg
#   inflating: ./train_set/2/13227.jpg
#   inflating: ./train_set/2/13235.jpg
#   inflating: ./train_set/2/13236.jpg
#   inflating: ./train_set/2/13246.jpg
#   inflating: ./train_set/2/13254.jpg
#   inflating: ./train_set/2/13256.jpg
#   inflating: ./train_set/2/13263.jpg
#   inflating: ./train_set/2/13323.jpg
#   inflating: ./train_set/2/13377.jpg
#   inflating: ./train_set/2/13415.jpg
#   inflating: ./train_set/2/13445.jpg
#   inflating: ./train_set/2/13497.jpg
#   inflating: ./train_set/2/13506.jpg
#   inflating: ./train_set/2/13600.jpg
#   inflating: ./train_set/2/13621.jpg
#   inflating: ./train_set/2/13632.jpg
#   inflating: ./train_set/2/1371.jpg
#   inflating: ./train_set/2/13728.jpg
#   inflating: ./train_set/2/13742.jpg
#   inflating: ./train_set/2/13761.jpg
#   inflating: ./train_set/2/13772.jpg
#   inflating: ./train_set/2/13816.jpg
#   inflating: ./train_set/2/1382.jpg
#   inflating: ./train_set/2/13829.jpg
#   inflating: ./train_set/2/13845.jpg
#   inflating: ./train_set/2/13865.jpg
#   inflating: ./train_set/2/13875.jpg
#   inflating: ./train_set/2/13910.jpg
#   inflating: ./train_set/2/14005.jpg
#   inflating: ./train_set/2/14011.jpg
#   inflating: ./train_set/2/14030.jpg
#   inflating: ./train_set/2/14040.jpg
#   inflating: ./train_set/2/14061.jpg
#   inflating: ./train_set/2/14068.jpg
#   inflating: ./train_set/2/14082.jpg
#   inflating: ./train_set/2/14091.jpg
#   inflating: ./train_set/2/14167.jpg
#   inflating: ./train_set/2/14198.jpg
#   inflating: ./train_set/2/14230.jpg
#   inflating: ./train_set/2/14267.jpg
#   inflating: ./train_set/2/14273.jpg
#   inflating: ./train_set/2/14301.jpg
#   inflating: ./train_set/2/14332.jpg
#   inflating: ./train_set/2/14337.jpg
#   inflating: ./train_set/2/14360.jpg
#   inflating: ./train_set/2/14374.jpg
#   inflating: ./train_set/2/14391.jpg
#   inflating: ./train_set/2/14507.jpg
#   inflating: ./train_set/2/14532.jpg
#   inflating: ./train_set/2/14535.jpg
#   inflating: ./train_set/2/14599.jpg
#   inflating: ./train_set/2/14641.jpg
#   inflating: ./train_set/2/14643.jpg
#   inflating: ./train_set/2/14651.jpg
#   inflating: ./train_set/2/14664.jpg
#   inflating: ./train_set/2/14677.jpg
#   inflating: ./train_set/2/14678.jpg
#   inflating: ./train_set/2/14682.jpg
#   inflating: ./train_set/2/14685.jpg
#   inflating: ./train_set/2/14692.jpg
#   inflating: ./train_set/2/14717.jpg
#   inflating: ./train_set/2/1472.jpg
#   inflating: ./train_set/2/14737.jpg
#   inflating: ./train_set/2/14770.jpg
#   inflating: ./train_set/2/14837.jpg
#   inflating: ./train_set/2/14842.jpg
#   inflating: ./train_set/2/14866.jpg
#   inflating: ./train_set/2/14886.jpg
#   inflating: ./train_set/2/15036.jpg
#   inflating: ./train_set/2/15075.jpg
#   inflating: ./train_set/2/15095.jpg
#   inflating: ./train_set/2/15112.jpg
#   inflating: ./train_set/2/15119.jpg
#   inflating: ./train_set/2/15156.jpg
#   inflating: ./train_set/2/1516.jpg
#   inflating: ./train_set/2/15171.jpg
#   inflating: ./train_set/2/15183.jpg
#   inflating: ./train_set/2/15197.jpg
#   inflating: ./train_set/2/15200.jpg
#   inflating: ./train_set/2/15218.jpg
#   inflating: ./train_set/2/15221.jpg
#   inflating: ./train_set/2/15243.jpg
#   inflating: ./train_set/2/15244.jpg
#   inflating: ./train_set/2/15274.jpg
#   inflating: ./train_set/2/15281.jpg
#   inflating: ./train_set/2/15295.jpg
#   inflating: ./train_set/2/15339.jpg
#   inflating: ./train_set/2/15340.jpg
#   inflating: ./train_set/2/15359.jpg
#   inflating: ./train_set/2/15374.jpg
#   inflating: ./train_set/2/15385.jpg
#   inflating: ./train_set/2/15407.jpg
#   inflating: ./train_set/2/15425.jpg
#   inflating: ./train_set/2/15469.jpg
#   inflating: ./train_set/2/15485.jpg
#   inflating: ./train_set/2/15505.jpg
#   inflating: ./train_set/2/15519.jpg
#   inflating: ./train_set/2/15546.jpg
#   inflating: ./train_set/2/15567.jpg
#   inflating: ./train_set/2/15618.jpg
#   inflating: ./train_set/2/15664.jpg
#   inflating: ./train_set/2/15677.jpg
#   inflating: ./train_set/2/15680.jpg
#   inflating: ./train_set/2/15715.jpg
#   inflating: ./train_set/2/15773.jpg
#   inflating: ./train_set/2/15807.jpg
#   inflating: ./train_set/2/15813.jpg
#   inflating: ./train_set/2/15860.jpg
#   inflating: ./train_set/2/15934.jpg
#   inflating: ./train_set/2/15954.jpg
#   inflating: ./train_set/2/16034.jpg
#   inflating: ./train_set/2/16037.jpg
#   inflating: ./train_set/2/16045.jpg
#   inflating: ./train_set/2/16052.jpg
#   inflating: ./train_set/2/16056.jpg
#   inflating: ./train_set/2/16066.jpg
#   inflating: ./train_set/2/16107.jpg
#   inflating: ./train_set/2/16109.jpg
#   inflating: ./train_set/2/16110.jpg
#   inflating: ./train_set/2/16114.jpg
#   inflating: ./train_set/2/16127.jpg
#   inflating: ./train_set/2/16216.jpg
#   inflating: ./train_set/2/16219.jpg
#   inflating: ./train_set/2/16224.jpg
#   inflating: ./train_set/2/16257.jpg
#   inflating: ./train_set/2/16279.jpg
#   inflating: ./train_set/2/16301.jpg
#   inflating: ./train_set/2/16310.jpg
#   inflating: ./train_set/2/16325.jpg
#   inflating: ./train_set/2/16354.jpg
#   inflating: ./train_set/2/16371.jpg
#   inflating: ./train_set/2/16413.jpg
#   inflating: ./train_set/2/16432.jpg
#   inflating: ./train_set/2/16438.jpg
#   inflating: ./train_set/2/16472.jpg
#   inflating: ./train_set/2/16474.jpg
# ...
#   inflating: ./train_set/6/2340.jpg
#   inflating: ./train_set/6/2341.jpg
#   inflating: ./train_set/6/2376.jpg
#   inflating: ./train_set/6/2386.jpg
#   inflating: ./train_set/6/240.jpg
#   inflating: ./train_set/6/2423.jpg
#   inflating: ./train_set/6/2474.jpg
#   inflating: ./train_set/6/2516.jpg
#   inflating: ./train_set/6/2530.jpg
#   inflating: ./train_set/6/2536.jpg
#   inflating: ./train_set/6/2549.jpg
#   inflating: ./train_set/6/2550.jpg
#   inflating: ./train_set/6/2551.jpg
#   inflating: ./train_set/6/2552.jpg
#   inflating: ./train_set/6/2553.jpg
#   inflating: ./train_set/6/2603.jpg
#   inflating: ./train_set/6/262.jpg
#   inflating: ./train_set/6/2631.jpg
#   inflating: ./train_set/6/2639.jpg
#   inflating: ./train_set/6/2668.jpg
#   inflating: ./train_set/6/2700.jpg
#   inflating: ./train_set/6/2734.jpg
#   inflating: ./train_set/6/2762.jpg
#   inflating: ./train_set/6/2763.jpg
#   inflating: ./train_set/6/2768.jpg
#   inflating: ./train_set/6/2779.jpg
#   inflating: ./train_set/6/2793.jpg
#   inflating: ./train_set/6/2833.jpg
#   inflating: ./train_set/6/2842.jpg
#   inflating: ./train_set/6/2855.jpg
#   inflating: ./train_set/6/2880.jpg
#   inflating: ./train_set/6/2889.jpg
#   inflating: ./train_set/6/292.jpg
#   inflating: ./train_set/6/2974.jpg
#   inflating: ./train_set/6/2975.jpg
#   inflating: ./train_set/6/3001.jpg
#   inflating: ./train_set/6/3081.jpg
#   inflating: ./train_set/6/3102.jpg
#   inflating: ./train_set/6/3105.jpg
#   inflating: ./train_set/6/3117.jpg
#   inflating: ./train_set/6/3150.jpg
#   inflating: ./train_set/6/3157.jpg
#   inflating: ./train_set/6/3201.jpg
#   inflating: ./train_set/6/3214.jpg
#   inflating: ./train_set/6/3221.jpg
#   inflating: ./train_set/6/3301.jpg
#   inflating: ./train_set/6/3303.jpg
#   inflating: ./train_set/6/3331.jpg
#   inflating: ./train_set/6/3367.jpg
#   inflating: ./train_set/6/3371.jpg
#   inflating: ./train_set/6/3392.jpg
#   inflating: ./train_set/6/3428.jpg
#   inflating: ./train_set/6/3433.jpg
#   inflating: ./train_set/6/3459.jpg
#   inflating: ./train_set/6/3464.jpg
#   inflating: ./train_set/6/3469.jpg
#   inflating: ./train_set/6/3481.jpg
#   inflating: ./train_set/6/3498.jpg
#   inflating: ./train_set/6/3501.jpg
#   inflating: ./train_set/6/3522.jpg
#   inflating: ./train_set/6/3523.jpg
#   inflating: ./train_set/6/3528.jpg
#   inflating: ./train_set/6/3538.jpg
#   inflating: ./train_set/6/3549.jpg
#   inflating: ./train_set/6/3561.jpg
#   inflating: ./train_set/6/3563.jpg
#   inflating: ./train_set/6/3577.jpg
#   inflating: ./train_set/6/3583.jpg
#   inflating: ./train_set/6/3595.jpg
#   inflating: ./train_set/6/3603.jpg
#   inflating: ./train_set/6/3615.jpg
#   inflating: ./train_set/6/3623.jpg
#   inflating: ./train_set/6/3645.jpg
#   inflating: ./train_set/6/3665.jpg
#   inflating: ./train_set/6/3719.jpg
#   inflating: ./train_set/6/3727.jpg
#   inflating: ./train_set/6/3758.jpg
#   inflating: ./train_set/6/3763.jpg
#   inflating: ./train_set/6/3765.jpg
#   inflating: ./train_set/6/3782.jpg
#   inflating: ./train_set/6/3806.jpg
#   inflating: ./train_set/6/3820.jpg
#   inflating: ./train_set/6/3830.jpg
#   inflating: ./train_set/6/3849.jpg
#   inflating: ./train_set/6/3857.jpg
#   inflating: ./train_set/6/3895.jpg
#   inflating: ./train_set/6/3918.jpg
#   inflating: ./train_set/6/3923.jpg
#   inflating: ./train_set/6/3924.jpg
#   inflating: ./train_set/6/3927.jpg
#   inflating: ./train_set/6/3931.jpg
#   inflating: ./train_set/6/4067.jpg
#   inflating: ./train_set/6/4091.jpg
#   inflating: ./train_set/6/4109.jpg
#   inflating: ./train_set/6/4118.jpg
#   inflating: ./train_set/6/412.jpg
#   inflating: ./train_set/6/4155.jpg
#   inflating: ./train_set/6/4156.jpg
#   inflating: ./train_set/6/4166.jpg
#   inflating: ./train_set/6/4199.jpg
#   inflating: ./train_set/6/4227.jpg
#   inflating: ./train_set/6/4235.jpg
#   inflating: ./train_set/6/4242.jpg
#   inflating: ./train_set/6/4252.jpg
#   inflating: ./train_set/6/426.jpg
#   inflating: ./train_set/6/4260.jpg
#   inflating: ./train_set/6/4264.jpg
#   inflating: ./train_set/6/4270.jpg
#   inflating: ./train_set/6/4275.jpg
#   inflating: ./train_set/6/429.jpg
#   inflating: ./train_set/6/4304.jpg
#   inflating: ./train_set/6/4350.jpg
#   inflating: ./train_set/6/438.jpg
#   inflating: ./train_set/6/4422.jpg
#   inflating: ./train_set/6/443.jpg
#   inflating: ./train_set/6/4444.jpg
#   inflating: ./train_set/6/4455.jpg
#   inflating: ./train_set/6/4469.jpg
#   inflating: ./train_set/6/4482.jpg
#   inflating: ./train_set/6/4488.jpg
#   inflating: ./train_set/6/4489.jpg
#   inflating: ./train_set/6/449.jpg
#   inflating: ./train_set/6/4490.jpg
#   inflating: ./train_set/6/4491.jpg
#   inflating: ./train_set/6/451.jpg
#   inflating: ./train_set/6/4579.jpg
#   inflating: ./train_set/6/4582.jpg
#   inflating: ./train_set/6/4587.jpg
#   inflating: ./train_set/6/4598.jpg
#   inflating: ./train_set/6/4599.jpg
#   inflating: ./train_set/6/4707.jpg
#   inflating: ./train_set/6/4773.jpg
#   inflating: ./train_set/6/478.jpg
#   inflating: ./train_set/6/4792.jpg
#   inflating: ./train_set/6/4798.jpg
#   inflating: ./train_set/6/4813.jpg
#   inflating: ./train_set/6/4834.jpg
#   inflating: ./train_set/6/484.jpg
#   inflating: ./train_set/6/4846.jpg
#   inflating: ./train_set/6/4868.jpg
#   inflating: ./train_set/6/4893.jpg
#   inflating: ./train_set/6/490.jpg
#   inflating: ./train_set/6/4902.jpg
#   inflating: ./train_set/6/4918.jpg
#   inflating: ./train_set/6/494.jpg
#   inflating: ./train_set/6/4947.jpg
#   inflating: ./train_set/6/4968.jpg
#   inflating: ./train_set/6/4993.jpg
#   inflating: ./train_set/6/4994.jpg
#   inflating: ./train_set/6/4997.jpg
#   inflating: ./train_set/6/5057.jpg
#   inflating: ./train_set/6/5062.jpg
#   inflating: ./train_set/6/5082.jpg
#   inflating: ./train_set/6/5084.jpg
#   inflating: ./train_set/6/5117.jpg
#   inflating: ./train_set/6/5145.jpg
#   inflating: ./train_set/6/5195.jpg
#   inflating: ./train_set/6/5197.jpg
#   inflating: ./train_set/6/5207.jpg
#   inflating: ./train_set/6/5269.jpg
#   inflating: ./train_set/6/5275.jpg
#   inflating: ./train_set/6/5315.jpg
#   inflating: ./train_set/6/5319.jpg
#   inflating: ./train_set/6/534.jpg
#   inflating: ./train_set/6/5347.jpg
#   inflating: ./train_set/6/5353.jpg
#   inflating: ./train_set/6/5395.jpg
#   inflating: ./train_set/6/5429.jpg
#   inflating: ./train_set/6/5475.jpg
#   inflating: ./train_set/6/5493.jpg
#   inflating: ./train_set/6/5494.jpg
#   inflating: ./train_set/6/5523.jpg
#   inflating: ./train_set/6/5539.jpg
#   inflating: ./train_set/6/5562.jpg
#   inflating: ./train_set/6/5596.jpg
#   inflating: ./train_set/6/5613.jpg
#   inflating: ./train_set/6/5614.jpg
#   inflating: ./train_set/6/5632.jpg
#   inflating: ./train_set/6/5633.jpg
#   inflating: ./train_set/6/568.jpg
#   inflating: ./train_set/6/5681.jpg
#   inflating: ./train_set/6/569.jpg
#   inflating: ./train_set/6/5709.jpg
#   inflating: ./train_set/6/5713.jpg
#   inflating: ./train_set/6/5722.jpg
#   inflating: ./train_set/6/5731.jpg
#   inflating: ./train_set/6/5779.jpg
#   inflating: ./train_set/6/5781.jpg
#   inflating: ./train_set/6/58.jpg
#   inflating: ./train_set/6/5809.jpg
#   inflating: ./train_set/6/5815.jpg
#   inflating: ./train_set/6/5850.jpg
#   inflating: ./train_set/6/5857.jpg
#   inflating: ./train_set/6/5879.jpg
#   inflating: ./train_set/6/5929.jpg
#   inflating: ./train_set/6/5934.jpg
#   inflating: ./train_set/6/5977.jpg
#   inflating: ./train_set/6/5986.jpg
#   inflating: ./train_set/6/5995.jpg
#   inflating: ./train_set/6/6005.jpg
#   inflating: ./train_set/6/601.jpg
#   inflating: ./train_set/6/6031.jpg
#   inflating: ./train_set/6/6064.jpg
#   inflating: ./train_set/6/6071.jpg
#   inflating: ./train_set/6/6075.jpg
#   inflating: ./train_set/6/6091.jpg
#   inflating: ./train_set/6/6095.jpg
#   inflating: ./train_set/6/6108.jpg
#   inflating: ./train_set/6/6109.jpg
#   inflating: ./train_set/6/6134.jpg
#   inflating: ./train_set/6/6147.jpg
#   inflating: ./train_set/6/6231.jpg
#   inflating: ./train_set/6/6234.jpg
#   inflating: ./train_set/6/6251.jpg
#   inflating: ./train_set/6/6290.jpg
#   inflating: ./train_set/6/6307.jpg
#   inflating: ./train_set/6/6317.jpg
#   inflating: ./train_set/6/6324.jpg
#   inflating: ./train_set/6/6345.jpg
#   inflating: ./train_set/6/6383.jpg
#   inflating: ./train_set/6/6398.jpg
#   inflating: ./train_set/6/6415.jpg
#   inflating: ./train_set/6/6437.jpg
#   inflating: ./train_set/6/6485.jpg
#   inflating: ./train_set/6/6492.jpg
#   inflating: ./train_set/6/6513.jpg
#   inflating: ./train_set/6/6539.jpg
#   inflating: ./train_set/6/6562.jpg
#   inflating: ./train_set/6/6582.jpg
#   inflating: ./train_set/6/6633.jpg
#   inflating: ./train_set/6/6639.jpg
#   inflating: ./train_set/6/6679.jpg
#   inflating: ./train_set/6/6685.jpg
#   inflating: ./train_set/6/6707.jpg
#   inflating: ./train_set/6/6710.jpg
#   inflating: ./train_set/6/6761.jpg
#   inflating: ./train_set/6/6852.jpg
#   inflating: ./train_set/6/6858.jpg
#   inflating: ./train_set/6/6883.jpg
#   inflating: ./train_set/6/6930.jpg
#   inflating: ./train_set/6/6956.jpg
#   inflating: ./train_set/6/6959.jpg
#   inflating: ./train_set/6/6966.jpg
#   inflating: ./train_set/6/6992.jpg
#   inflating: ./train_set/6/7007.jpg
#   inflating: ./train_set/6/7027.jpg
#   inflating: ./train_set/6/7031.jpg
#   inflating: ./train_set/6/7042.jpg
#   inflating: ./train_set/6/7069.jpg
#   inflating: ./train_set/6/7077.jpg
#   inflating: ./train_set/6/7095.jpg
#   inflating: ./train_set/6/7098.jpg
#   inflating: ./train_set/6/7101.jpg
#   inflating: ./train_set/6/7114.jpg
#   inflating: ./train_set/6/7148.jpg
#   inflating: ./train_set/6/7160.jpg
#   inflating: ./train_set/6/721.jpg
#   inflating: ./train_set/6/7222.jpg
#   inflating: ./train_set/6/7293.jpg
#   inflating: ./train_set/6/7311.jpg
#   inflating: ./train_set/6/7352.jpg
#   inflating: ./train_set/6/7377.jpg
#   inflating: ./train_set/6/7465.jpg
#   inflating: ./train_set/6/747.jpg
#   inflating: ./train_set/6/749.jpg
#   inflating: ./train_set/6/7495.jpg
#   inflating: ./train_set/6/7499.jpg
#   inflating: ./train_set/6/7511.jpg
#   inflating: ./train_set/6/7518.jpg
#   inflating: ./train_set/6/7526.jpg
#   inflating: ./train_set/6/7529.jpg
#   inflating: ./train_set/6/7561.jpg
#   inflating: ./train_set/6/7603.jpg
#   inflating: ./train_set/6/7612.jpg
#   inflating: ./train_set/6/7652.jpg
#   inflating: ./train_set/6/7663.jpg
#   inflating: ./train_set/6/7698.jpg
#   inflating: ./train_set/6/770.jpg
#   inflating: ./train_set/6/7715.jpg
#   inflating: ./train_set/6/772.jpg
#   inflating: ./train_set/6/7721.jpg
#   inflating: ./train_set/6/7770.jpg
#   inflating: ./train_set/6/7787.jpg
#   inflating: ./train_set/6/7792.jpg
#   inflating: ./train_set/6/781.jpg
#   inflating: ./train_set/6/7849.jpg
#   inflating: ./train_set/6/7857.jpg
#   inflating: ./train_set/6/7882.jpg
#   inflating: ./train_set/6/7887.jpg
#   inflating: ./train_set/6/7888.jpg
#   inflating: ./train_set/6/7902.jpg
#   inflating: ./train_set/6/7917.jpg
#   inflating: ./train_set/6/7919.jpg
#   inflating: ./train_set/6/7924.jpg
#   inflating: ./train_set/6/7934.jpg
#   inflating: ./train_set/6/7936.jpg
#   inflating: ./train_set/6/7985.jpg
#   inflating: ./train_set/6/7994.jpg
#   inflating: ./train_set/6/801.jpg
#   inflating: ./train_set/6/8017.jpg
#   inflating: ./train_set/6/8053.jpg
#   inflating: ./train_set/6/8091.jpg
#   inflating: ./train_set/6/8097.jpg
#   inflating: ./train_set/6/8148.jpg
#   inflating: ./train_set/6/8151.jpg
#   inflating: ./train_set/6/8153.jpg
#   inflating: ./train_set/6/8188.jpg
#   inflating: ./train_set/6/8200.jpg
#   inflating: ./train_set/6/8225.jpg
#   inflating: ./train_set/6/8241.jpg
#   inflating: ./train_set/6/8264.jpg
#   inflating: ./train_set/6/8267.jpg
#   inflating: ./train_set/6/8287.jpg
#   inflating: ./train_set/6/8301.jpg
#   inflating: ./train_set/6/8305.jpg
#   inflating: ./train_set/6/8336.jpg
#   inflating: ./train_set/6/8352.jpg
#   inflating: ./train_set/6/8357.jpg
#   inflating: ./train_set/6/836.jpg
#   inflating: ./train_set/6/8377.jpg
#   inflating: ./train_set/6/8383.jpg
#   inflating: ./train_set/6/8393.jpg
#   inflating: ./train_set/6/8441.jpg
#   inflating: ./train_set/6/8456.jpg
#   inflating: ./train_set/6/8473.jpg
#   inflating: ./train_set/6/8476.jpg
#   inflating: ./train_set/6/8488.jpg
#   inflating: ./train_set/6/8492.jpg
#   inflating: ./train_set/6/8508.jpg
#   inflating: ./train_set/6/852.jpg
#   inflating: ./train_set/6/8528.jpg
#   inflating: ./train_set/6/8530.jpg
#   inflating: ./train_set/6/856.jpg
#   inflating: ./train_set/6/8568.jpg
#   inflating: ./train_set/6/8569.jpg
#   inflating: ./train_set/6/8605.jpg
#   inflating: ./train_set/6/8614.jpg
#   inflating: ./train_set/6/8646.jpg
#   inflating: ./train_set/6/866.jpg
#   inflating: ./train_set/6/8679.jpg
#   inflating: ./train_set/6/868.jpg
#   inflating: ./train_set/6/8704.jpg
#   inflating: ./train_set/6/872.jpg
#   inflating: ./train_set/6/8722.jpg
#   inflating: ./train_set/6/8744.jpg
#   inflating: ./train_set/6/877.jpg
#   inflating: ./train_set/6/8771.jpg
#   inflating: ./train_set/6/8789.jpg
#   inflating: ./train_set/6/8790.jpg
#   inflating: ./train_set/6/883.jpg
#   inflating: ./train_set/6/8872.jpg
#   inflating: ./train_set/6/8894.jpg
#   inflating: ./train_set/6/8974.jpg
#   inflating: ./train_set/6/8986.jpg
#   inflating: ./train_set/6/9.jpg
#   inflating: ./train_set/6/9038.jpg
#   inflating: ./train_set/6/9046.jpg
#   inflating: ./train_set/6/9073.jpg
#   inflating: ./train_set/6/9131.jpg
#   inflating: ./train_set/6/9132.jpg
#   inflating: ./train_set/6/9133.jpg
#   inflating: ./train_set/6/9137.jpg
#   inflating: ./train_set/6/918.jpg
#   inflating: ./train_set/6/9199.jpg
#   inflating: ./train_set/6/9221.jpg
#   inflating: ./train_set/6/9234.jpg
#   inflating: ./train_set/6/9291.jpg
#   inflating: ./train_set/6/9316.jpg
#   inflating: ./train_set/6/9346.jpg
#   inflating: ./train_set/6/9361.jpg
#   inflating: ./train_set/6/9362.jpg
#   inflating: ./train_set/6/938.jpg
#   inflating: ./train_set/6/9390.jpg
#   inflating: ./train_set/6/9415.jpg
#   inflating: ./train_set/6/9435.jpg
#   inflating: ./train_set/6/9437.jpg
#   inflating: ./train_set/6/9446.jpg
#   inflating: ./train_set/6/9492.jpg
#   inflating: ./train_set/6/9509.jpg
#   inflating: ./train_set/6/9518.jpg
#   inflating: ./train_set/6/952.jpg
#   inflating: ./train_set/6/9552.jpg
#   inflating: ./train_set/6/9558.jpg
#   inflating: ./train_set/6/9569.jpg
#   inflating: ./train_set/6/9587.jpg
#   inflating: ./train_set/6/9595.jpg
#   inflating: ./train_set/6/9605.jpg
#   inflating: ./train_set/6/9632.jpg
#   inflating: ./train_set/6/9658.jpg
#   inflating: ./train_set/6/9686.jpg
#   inflating: ./train_set/6/9700.jpg
#   inflating: ./train_set/6/9707.jpg
#   inflating: ./train_set/6/9715.jpg
#   inflating: ./train_set/6/9742.jpg
#   inflating: ./train_set/6/9795.jpg
#   inflating: ./train_set/6/9801.jpg
#   inflating: ./train_set/6/9829.jpg
#   inflating: ./train_set/6/9836.jpg
#   inflating: ./train_set/6/9848.jpg
#   inflating: ./train_set/6/9855.jpg
#   inflating: ./train_set/6/9865.jpg
#   inflating: ./train_set/6/9875.jpg
#   inflating: ./train_set/6/9908.jpg
#   inflating: ./train_set/6/9920.jpg
#   inflating: ./train_set/6/9973.jpg
#   inflating: ./train_set/6/9974.jpg
# --2020-03-15 02:47:06--  http://yucanwu.com/aps360/set_v_3500.zip
# Resolving yucanwu.com (yucanwu.com)... 207.148.19.24
# Connecting to yucanwu.com (yucanwu.com)|207.148.19.24|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58821528 (56M) [application/zip]
# Saving to: ‘set_v_3500.zip’
#
# set_v_3500.zip      100%[===================>]  56.10M  14.9MB/s    in 5.0s
#
# 2020-03-15 02:47:12 (11.2 MB/s) - ‘set_v_3500.zip’ saved [58821528/58821528]
#
# set_a_5600.zip	train_set	  valid_set
# set_v_3500.zip	train_set_tensor  valid_set_tensor

# %%
# obtain data
from torchvision import datasets, transforms
import warnings

# PATH_OF_DATA = "/content/dataset/"
#PATH_OF_DATA = "/content/drive/My Drive/APS360/Emotion_Detection_CNN"
#PATH_OF_DATA = "/Users/kexinli/PycharmProjects/RECTnet"


def get_one_data_loader(path=PATH_TRAIN, batch_size=1, num_workers=1):
    """ NEW d
    """
    data_transform = transforms.Compose([transforms.Resize(224, 224),
                                        transforms.ToTensor(),
                                        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
    dataset = datasets.ImageFolder(path, transform=data_transform)
    loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                           num_workers=num_workers, shuffle=True)
    return loader

# %%
# test if works
train_loader = get_one_data_loader()
classes = ['0: Neutral', '1: Happiness', 
           '2: Sadness', '3: Surprise', 
           '4: Fear', '5: Disgust', '6: Anger']

k = 0
for images, labels in train_loader:
    # since batch_size = 1, there is only 1 image in `images`
    image = images[0]
    # place the colour channel at the end, instead of at the beginning
    img = np.transpose(image, [1,2,0])
    # normalize pixel intensity values to [0, 1]
    img = img / 2 + 0.5
    plt.subplot(2, 3, k+1)
    plt.axis('off')
    plt.imshow(img)
    plt.title(classes[labels[0]])

    k += 1
    if k >= 6:
        break

# %% [markdown]
# ##Helper functions

# %%
###############################################################################
# Training
def get_model_name(name, batch_size, learning_rate, epoch):
    """ Generate a name for the model consisting of all the hyperparameter values

    Args:
        config: Configuration object containing the hyperparameters
    Returns:
        path: A string with the hyperparameter name and value concatenated
    """
    path = "model_{0}_bs{1}_lr{2}_epoch{3}".format(name,
                                                   batch_size,
                                                   learning_rate,
                                                   epoch)
    return path

###############################################################################
# Training Curve
def plot_training_curve(path):
    """ Plots the training curve for a model run, given the csv files
    containing the train/validation error/loss.

    Args:
        path: The base path of the csv files produced during training
    """
    train_err = np.loadtxt("{}_train_err.csv".format(path))
    val_err = np.loadtxt("{}_val_err.csv".format(path))
    train_loss = np.loadtxt("{}_train_loss.csv".format(path))
    val_loss = np.loadtxt("{}_val_loss.csv".format(path))
    plt.title("Train vs Validation Error")
    n = len(train_err) # number of epochs
    plt.plot(range(1,n+1), train_err, label="Train")
    plt.plot(range(1,n+1), val_err, label="Validation")
    plt.xlabel("Epoch")
    plt.ylabel("Error")
    plt.legend(loc='best')
    plt.show()
    plt.title("Train vs Validation Loss")
    plt.plot(range(1,n+1), train_loss, label="Train")
    plt.plot(range(1,n+1), val_loss, label="Validation")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend(loc='best')
    plt.show()

def get_accuracy(model, data, train=False):
    with torch.no_grad():
        correct = 0
        total = 0
        #for imgs, labels in torch.utils.data.DataLoader(data, batch_size=64):
        for imgs, labels in data: 
            
            #############################################
            #To Enable GPU Usage
            if use_cuda and torch.cuda.is_available():
                imgs = imgs.cuda()
                labels = labels.cuda()
            #############################################
            
            
            output = model(imgs)
            
            #select index with maximum prediction score
            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(labels.view_as(pred)).sum().item()
            total += imgs.shape[0]

            del imgs
            del labels
        return correct / total

def plot_training_curve(path):
    import matplotlib.pyplot as plt

    train_losses = np.loadtxt("{}_train_loss.csv".format(path))
    train_acc = np.loadtxt("{}_train_acc.csv".format(path))
    val_losses = np.loadtxt("{}_val_loss.csv".format(path))
    val_acc = np.loadtxt("{}_val_acc.csv".format(path))

    plt.title("Training Curve")

    n = len(train_losses)
    m = len(val_losses)
    # print(n, m)
    plt.plot(range(1, n + 1), train_losses, label="Train")
    plt.plot(range(1, m + 1), val_losses, label="Validation")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend(loc='best')
    plt.show()

    plt.title("Training Curve")
    plt.plot(range(1, n + 1), train_acc, label="Train")
    plt.plot(range(1, m + 1), val_acc, label="Validation")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend(loc='best')
    plt.show()
    print("Final Training Loss: {}".format(train_losses[-1]))
    print("Final Validation Loss: {}".format(val_losses[-1]))
    print("Final Training Accuracy: {}".format(train_acc[-1]))
    print("Final Validation Accuracy: {}".format(val_acc[-1]))

# %%
def train(model, data_path, batch_size=64, learning_rate=0.01, num_epochs=1):
    target_classes = ['0', '1', '2', '3', '4', '5', '6']
    train_feature, val_feature = get_feature_loader(batch_size)
    # Fixed PyTorch random seed for reproducible result
    torch.manual_seed(1000)
    
    # Obtain the PyTorch data loader objects to load batches of the datasets
    
    
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)
    #optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    # print(model.parameters())
    iters, viters, train_losses, val_losses, train_acc, val_acc = [], [], [], [], [], []

    # training
    n = 0 # the number of iterations
    m = 0
    for epoch in range(num_epochs):
        train_loss_tot = 0
        val_loss_tot = 0
        train_item = 0
        val_item = 0
        print("Starting epoch ", epoch)

        for features, labels in iter(train_feature):
            #############################################
            #To Enable GPU Usage
            if use_cuda and torch.cuda.is_available():
              features = features.cuda()
              labels = labels.cuda()
            #############################################
            
              
            out = model(features)             # forward pass
            loss = criterion(out, labels) # compute the total loss
            loss.backward()               # backward pass (compute parameter updates)
            optimizer.step()              # make the updates for each parameter
            optimizer.zero_grad()         # a clean up step for PyTorch
            train_loss_tot += loss
            train_item += 1
            iters.append(n)
            n += 1

              
        for features, labels in iter(val_feature):
           #############################################
            #To Enable GPU Usage
            if use_cuda and torch.cuda.is_available():
              features = features.cuda()
              labels = labels.cuda()
            #############################################
            
            out = model(features)             # forward pass
            loss = criterion(out, labels) # compute the total loss
            val_loss_tot += loss
            val_item += 1
            viters.append(m)
            m += 1
              
        # save the training info for every few (1) epoches:
        #iters.append(n)
        train_losses.append(float(train_loss_tot)/train_item)             # compute *average* loss
        get_acc = get_accuracy(model, train_feature)
        train_acc.append(get_acc) # compute training accuracy 

        val_losses.append(float(val_loss_tot)/val_item)             # compute *average* loss
        get_acc_val = get_accuracy(model, val_feature)
        val_acc.append(get_acc_val)  # compute validation accuracy

        #print("Iter {}: ".format(n))
        print("Train loss: {}, Train acc: {}".format(float(train_loss_tot)/train_item, get_acc))
        print("Validation loss: {}, Validation acc: {}".format(float(val_loss_tot)/val_item, get_acc_val))
  
        # (checkpoint)
        model_path = get_model_name(model.name, batch_size, learning_rate, epoch)
        torch.save(model.state_dict(), model_path)  
        # for plotting later (checkpoint)
        np.savetxt("{}_train_loss.csv".format(model_path), train_losses)
        np.savetxt("{}_train_acc.csv".format(model_path), train_acc)
        np.savetxt("{}_val_loss.csv".format(model_path), val_losses)
        np.savetxt("{}_val_acc.csv".format(model_path), val_acc)      
    print("Finished training")

# %%
# import torchvision.models
# torchvision.models.inception.inception_v3(pretrained=True)
import torchvision.models
alexnet = torchvision.models.alexnet(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /root/.cache/torch/checkpoints/alexnet-owt-4df8aa71.pth
# HBox(children=(IntProgress(value=0, max=244418560), HTML(value='')))

# %%
# img = ... a PyTorch tensor with shape [N,3,224,224] containing hand images ...
def dataset_to_features(data_set):
  feature_set = []
  for imgs, labels in data_set:
    features = alexnet.features(imgs)
    features = torch.from_numpy(features.detach().numpy())
    feature_set.append((features, labels))
  return feature_set

# %%
# !rm -r /content/train_set_tensor
# !rm -r /content/valid_set_tensor
# !mkdir /content/train_set_tensor
# !mkdir /content/valid_set_tensor
# !mkdir /content/train_set_tensor/0
# !mkdir /content/train_set_tensor/1
# !mkdir /content/train_set_tensor/2
# !mkdir /content/train_set_tensor/3
# !mkdir /content/train_set_tensor/4
# !mkdir /content/train_set_tensor/5
# !mkdir /content/train_set_tensor/6
# !mkdir /content/valid_set_tensor/0
# !mkdir /content/valid_set_tensor/1
# !mkdir /content/valid_set_tensor/2
# !mkdir /content/valid_set_tensor/3
# !mkdir /content/valid_set_tensor/4
# !mkdir /content/valid_set_tensor/5
# !mkdir /content/valid_set_tensor/6

# %%
batch_size = 1
import os
import torchvision.models
alexnet = torchvision.models.alexnet(pretrained=True)

train_loader = get_one_data_loader(path=PATH_TRAIN, batch_size=batch_size)
val_loader = get_one_data_loader(path=PATH_VALID, batch_size=batch_size)
# location on Google Drive
# master_path = '/content/drive/My Drive/APS360/Emotion_Detection_CNN'
master_path = '/content'
print("so far so good")
target_classes = ['0', '1', '2', '3', '4', '5', '6']


# save features to folder as tensors
n = 0
for img, label in train_loader:
  if label < 7:
    features = alexnet.features(img)
    features_tensor = torch.from_numpy(features.detach().numpy())

    folder_name = master_path + '/train_set/' + str(target_classes[label])
    if not os.path.isdir(folder_name):
      os.mkdir(folder_name)
    torch.save(features_tensor.squeeze(0), master_path + '/train_set_tensor/'+ str(label.numpy()[0]) + '/' + str(n) + '.tensor')
    n += 1
print("--------------------------------------")
for img, label in val_loader:
  if label < 7:
    features = alexnet.features(img)
    features_tensor = torch.from_numpy(features.detach().numpy())

    folder_name = master_path + '/valid_set/' + str(target_classes[label])
    if not os.path.isdir(folder_name):
      os.mkdir(folder_name)
    torch.save(features_tensor.squeeze(0), master_path + '/valid_set_tensor/' + str(label.numpy()[0]) + '/' + str(n) + '.tensor')
    n += 1
print("======================================")
# for img, label in test_loader:
#   features = alexnet.features(img)
#   features_tensor = torch.from_numpy(features.detach().numpy())

#   folder_name = master_path + '/dataset_test/' + str(target_classes[label])
#   if not os.path.isdir(folder_name):
#     os.mkdir(folder_name)
#   torch.save(features_tensor.squeeze(0), master_path + '/dataset_test/' + '/tensor/' + str(n) + '.tensor')
#   n += 1
# Out:
# so far so good
# --------------------------------------
# ======================================

# %%
PATH_TRAIN_Feature = "/content/train_set_tensor"
PATH_VALID_Feature = "/content/valid_set_tensor"
def get_feature_loader(data_path, batch_size=1):
  train_feature = get_one_data_loader(PATH_TRAIN_Feature, batch_size)
  val_feature = get_one_data_loader(PATH_VALID_Feature, batch_size)
  # test_feature = dataset_to_features(test_loader)
  return train_feature, val_feature #, test_feature

# %%
def get_one_feature_loader(path=PATH_TRAIN_Feature, batch_size=1, num_workers=1):
    """ NEW d
    """
    
    dataset = torchvision.datasets.DatasetFolder(path, loader=torch.load, extensions=('.tensor'))
    loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                           num_workers=num_workers, shuffle=True)
    return loader

# %% [markdown]
# # ***Model Training***

# %%
def train_feature(model, batch_size=64, learning_rate=0.01, num_epochs=1):
    train_feature = get_one_feature_loader(PATH_TRAIN_Feature,batch_size)
    val_feature = get_one_feature_loader(PATH_VALID_Feature,batch_size)
    # Fixed PyTorch random seed for reproducible result
    torch.manual_seed(1000)
    
    # Obtain the PyTorch data loader objects to load batches of the datasets
    
    
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)
    #optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    # print(model.parameters())
    iters, viters, train_losses, val_losses, train_acc, val_acc = [], [], [], [], [], []

    # training
    n = 0 # the number of iterations
    m = 0
    for epoch in range(num_epochs):
        train_loss_tot = 0
        val_loss_tot = 0
        train_item = 0
        val_item = 0
        print("Starting epoch ", epoch)

        for features, labels in iter(train_feature):
            #############################################
            #To Enable GPU Usage
            if use_cuda and torch.cuda.is_available():
              features = features.cuda()
              labels = labels.cuda()
            #############################################
            
              
            out = model(features)             # forward pass
            loss = criterion(out, labels) # compute the total loss
            loss.backward()               # backward pass (compute parameter updates)
            optimizer.step()              # make the updates for each parameter
            optimizer.zero_grad()         # a clean up step for PyTorch
            train_loss_tot += loss
            train_item += 1
            iters.append(n)
            n += 1

              
        for features, labels in iter(val_feature):
           #############################################
            #To Enable GPU Usage
            if use_cuda and torch.cuda.is_available():
              features = features.cuda()
              labels = labels.cuda()
            #############################################
            
            out = model(features)             # forward pass
            loss = criterion(out, labels) # compute the total loss
            val_loss_tot += loss
            val_item += 1
            viters.append(m)
            m += 1
              
        # save the training info for every few (1) epoches:
        #iters.append(n)
        train_losses.append(float(train_loss_tot)/train_item)             # compute *average* loss
        get_acc = get_accuracy(model, train_feature)
        train_acc.append(get_acc) # compute training accuracy 

        val_losses.append(float(val_loss_tot)/val_item)             # compute *average* loss
        get_acc_val = get_accuracy(model, val_feature)
        val_acc.append(get_acc_val)  # compute validation accuracy

        #print("Iter {}: ".format(n))
        print("Train loss: {}, Train acc: {}".format(float(train_loss_tot)/train_item, get_acc))
        print("Validation loss: {}, Validation acc: {}".format(float(val_loss_tot)/val_item, get_acc_val))
  
        # (checkpoint)
        model_path = get_model_name(model.name, batch_size, learning_rate, epoch)
        torch.save(model.state_dict(), model_path)  
        # for plotting later (checkpoint)
        np.savetxt("{}_train_loss.csv".format(model_path), train_losses)
        np.savetxt("{}_train_acc.csv".format(model_path), train_acc)
        np.savetxt("{}_val_loss.csv".format(model_path), val_losses)
        np.savetxt("{}_val_acc.csv".format(model_path), val_acc)      
    print("Finished training")

# %%
class FaceRec(nn.Module):
      def __init__(self):
          super(FaceRec, self).__init__()
          self.name = "FaceRec"
          self.fc1 = nn.Linear(9216, 50)
          self.fc2 = nn.Linear(50, 7)

      def forward(self, x):
          x = x.view(-1, 9216)
          x = F.relu(self.fc1(x))
          x = F.dropout(x, training=self.training)
          x = self.fc2(x)
          
          return x

# %%
# training
use_cuda = True
model = FaceRec()
if use_cuda and torch.cuda.is_available():
  torch.cuda.empty_cache()
  model.cuda()
  print('CUDA is available!  Training on GPU ...')
else:
  print('CUDA is not available.  Training on CPU ...')
train_feature(model, batch_size=64, learning_rate=0.0002, num_epochs=40)
# Out:
# CUDA is available!  Training on GPU ...
# Starting epoch  0
# Train loss: 1.881871136752042, Train acc: 0.28517857142857145
# Validation loss: 1.8579306862571023, Validation acc: 0.22628571428571428
# Starting epoch  1
# Train loss: 1.7210440202192827, Train acc: 0.3682142857142857
# Validation loss: 1.7935487227006393, Validation acc: 0.26914285714285713
# Starting epoch  2
# Train loss: 1.6061214100230823, Train acc: 0.4094642857142857
# Validation loss: 1.7689726396040484, Validation acc: 0.29228571428571426
# Starting epoch  3
# Train loss: 1.5267481370405718, Train acc: 0.4467857142857143
# Validation loss: 1.7405467640269887, Validation acc: 0.318
# Starting epoch  4
# Train loss: 1.4651759754527698, Train acc: 0.47035714285714286
# Validation loss: 1.7481190074573865, Validation acc: 0.322
# Starting epoch  5
# Train loss: 1.4174557599154385, Train acc: 0.48732142857142857
# Validation loss: 1.7267078746448863, Validation acc: 0.336
# Starting epoch  6
# Train loss: 1.3677006634798916, Train acc: 0.4969642857142857
# Validation loss: 1.7371736006303267, Validation acc: 0.31942857142857145
# Starting epoch  7
# Train loss: 1.3264252922751687, Train acc: 0.5094642857142857
# Validation loss: 1.7012893676757812, Validation acc: 0.3417142857142857
# Starting epoch  8
# Train loss: 1.2904183647849343, Train acc: 0.52625
# Validation loss: 1.7036515669389205, Validation acc: 0.356
# Starting epoch  9
# Train loss: 1.2655806107954546, Train acc: 0.5466071428571428
# Validation loss: 1.6988770918412641, Validation acc: 0.3568571428571429
# Starting epoch  10
# Train loss: 1.2328853607177734, Train acc: 0.55
# Validation loss: 1.6863433837890625, Validation acc: 0.36028571428571426
# Starting epoch  11
# Train loss: 1.2140151804143733, Train acc: 0.5558928571428572
# Validation loss: 1.7110889781605114, Validation acc: 0.3617142857142857
# Starting epoch  12
# Train loss: 1.1881668784401633, Train acc: 0.56
# Validation loss: 1.7127491344105115, Validation acc: 0.36428571428571427
# Starting epoch  13
# Train loss: 1.1565773703835227, Train acc: 0.585
# Validation loss: 1.7009201049804688, Validation acc: 0.37914285714285717
# Starting epoch  14
# Train loss: 1.1496464989402078, Train acc: 0.5869642857142857
# Validation loss: 1.6733427567915482, Validation acc: 0.3737142857142857
# Starting epoch  15
# Train loss: 1.1183893030340022, Train acc: 0.6046428571428571
# Validation loss: 1.6793839888139204, Validation acc: 0.37457142857142856
# Starting epoch  16
# Train loss: 1.105028585954146, Train acc: 0.6019642857142857
# Validation loss: 1.6904998779296876, Validation acc: 0.3782857142857143
# Starting epoch  17
# Train loss: 1.082908803766424, Train acc: 0.6144642857142857
# Validation loss: 1.6812902277166193, Validation acc: 0.3851428571428571
# Starting epoch  18
# Train loss: 1.0546460585160689, Train acc: 0.6257142857142857
# Validation loss: 1.7229124589399858, Validation acc: 0.38371428571428573
# Starting epoch  19
# Train loss: 1.040221561085094, Train acc: 0.6341071428571429
# Validation loss: 1.7186947909268466, Validation acc: 0.38342857142857145
# Starting epoch  20
# Train loss: 1.0207407691261985, Train acc: 0.6460714285714285
# Validation loss: 1.6976002086292614, Validation acc: 0.38257142857142856
# Starting epoch  21
# Train loss: 1.002089500427246, Train acc: 0.65
# Validation loss: 1.7026426835493609, Validation acc: 0.388
# Starting epoch  22
# Train loss: 1.0040163560347124, Train acc: 0.6548214285714286
# Validation loss: 1.7301689841530539, Validation acc: 0.388
# Starting epoch  23
# Train loss: 0.9882857582785867, Train acc: 0.6635714285714286
# Validation loss: 1.6950257734818892, Validation acc: 0.4094285714285714
# Starting epoch  24
# Train loss: 0.9516037160700018, Train acc: 0.6648214285714286
# Validation loss: 1.7486815019087358, Validation acc: 0.3942857142857143
# Starting epoch  25
# Train loss: 0.9529758800159801, Train acc: 0.6723214285714286
# Validation loss: 1.7083525224165483, Validation acc: 0.3931428571428571
# Starting epoch  26
# Train loss: 0.9294070330533114, Train acc: 0.6732142857142858
# Validation loss: 1.742923251065341, Validation acc: 0.39571428571428574
# Starting epoch  27
# Train loss: 0.9296288923783735, Train acc: 0.6839285714285714
# Validation loss: 1.712501387162642, Validation acc: 0.39714285714285713
# Starting epoch  28
# Train loss: 0.9085484418002042, Train acc: 0.6810714285714285
# Validation loss: 1.7899394642223012, Validation acc: 0.39171428571428574
# Starting epoch  29
# Train loss: 0.9044832749800249, Train acc: 0.6892857142857143
# Validation loss: 1.7481690840287643, Validation acc: 0.3902857142857143
# Starting epoch  30
# Train loss: 0.8829484419389204, Train acc: 0.7030357142857143
# Validation loss: 1.7378412420099432, Validation acc: 0.40514285714285714
# Starting epoch  31
# Train loss: 0.8720325990156694, Train acc: 0.7121428571428572
# Validation loss: 1.7682260686700995, Validation acc: 0.3931428571428571
# Starting epoch  32
# Train loss: 0.8589200106534091, Train acc: 0.7016071428571429
# Validation loss: 1.782027782093395, Validation acc: 0.4065714285714286
# Starting epoch  33
# Train loss: 0.848611138083718, Train acc: 0.70125
# Validation loss: 1.740558554909446, Validation acc: 0.4065714285714286
# Starting epoch  34
# Train loss: 0.8319359692660245, Train acc: 0.72625
# Validation loss: 1.7164167924360796, Validation acc: 0.4062857142857143
# Starting epoch  35
# Train loss: 0.8221429478038441, Train acc: 0.7182142857142857
# Validation loss: 1.767573269930753, Validation acc: 0.41085714285714287
# Starting epoch  36
# Train loss: 0.8174798271872781, Train acc: 0.735
# Validation loss: 1.7499617143110795, Validation acc: 0.4037142857142857
# Starting epoch  37
# Train loss: 0.797576904296875, Train acc: 0.7360714285714286
# Validation loss: 1.8144485473632812, Validation acc: 0.4014285714285714
# Starting epoch  38
# Train loss: 0.7849693298339844, Train acc: 0.7439285714285714
# Validation loss: 1.772178788618608, Validation acc: 0.3911428571428571
# Starting epoch  39
# Train loss: 0.7608503861860796, Train acc: 0.7435714285714285
# Validation loss: 1.8207219904119318, Validation acc: 0.4117142857142857
# Finished training

# %%
model_path = get_model_name("FaceRec", batch_size=64, learning_rate=0.0002, epoch=20)
plot_training_curve(model_path)
# Out:
# Final Training Loss: 1.0207407691261985
# Final Validation Loss: 1.6976002086292614
# Final Training Accuracy: 0.6460714285714285
# Final Validation Accuracy: 0.38257142857142856
